# %%
import RAP_MASTER_LIB
#MY LIBRARIES -- towards the end of project/when you need a break write up documentaiton of libraries
#another library for plotting and testing
from rap_scrpr import *
from rap_db import *
from rap_clean import*
from rap_viz import *

estconn = pg2.connect(database='rap_songs', user='keenan', host='localhost', password='keenan')
#import nltk
#nltk.download()
#create_music_tables(estconn)

# %%
#new_artists = scrape_multi_artists(estconn, ['10sion'])
#create_music_tables(estconn, bypass = True)
#bulk_load(estconn, new_artists)
lst = ['Del', 'Eminem', 'Jay-Z', 'Chance', '50_Cent', 'Doom']
l2 = ['Doom']
works_pull = dict(zip(lst, construct_artists(estconn, art_list = lst)))
art_save(works_pull)

# %%
works = art_load(lst)

# %%
sub_works = {'Del':works['Del'], 'Chance':works['Chance'], 'Doom':works['Doom']}

# %%
vs = unique_verses_bar(sub_works.values())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="82379127-7e32-4006-812e-17a8168adaed" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("82379127-7e32-4006-812e-17a8168adaed", [{"type": "bar", "x": [88, 28, 67, 24, 67, 29, 100, 15, 30, 35], "orientation": "h", "text": ["Grab the microphone like he smack a rapper iPhone<br>PRhyme time, time's up, dial tone, smile's on<br>Show your teeth, known by the wild prone<br>All getters, pile on, gone since child grown<br>On the count, check, or catch a pound neck<br>for clownin around for rec', no disrespect<br>intended, said it, and meant it<br>Before it's invented, get it, did it, spent it<br>Keep the change, he needs that receipt, thanks<br>MC's need franks regardless of street rank<br>They feet stank, we never leave the beat blank<br><br>Song: Highs and Lows * -- (0.852)", "I get no kick from champagne<br>Their alcohol doesn't thrill me at all<br>So tell me why shouldn't it be true<br>I get a kick out of brew<br><br>Song: Appetizers: One Beer -- (0.857)", "War nine, frying swine to pork grinds<br>For trying to walk the fine line, thoughts flying<br>Had more fun with a crooked rookie<br>Went for his gun, cracked his skull like a fortune cookie<br>A mind reader, find out, speak, freaks bow<br>With the nine heater, beat feet and smile now<br>Ten paces, about face, chase me<br>We make it sound crazy than a case of M-80's<br><br>Song: Chinatown Wars (Like a Renegade) -- (0.866)", "If the new shoes fit better than the old ones, rock 'em black<br>I'm gonna pick up some cold ones and knock 'em back<br> <br><br>Song: Perfect Hair II -- (0.875)", "\"Duck Season 3\" officially in Haters Town<br>Be sure to bring your maters call, and lazer sounds<br>They flied in, migrated, that's why I waited<br>The whole time eye and balls dilated<br>Flier was faded, the date was right though<br>Hoe it ain't nuttin but my hound dog Nitro<br>Go get 'em boy, Villain found some dinners<br>After I finished skinnin 'em y'all can split the innards<br><br>Song: The Unexpected -- (0.896)", "It's like a jungle, 24/7, 365<br>.44, high score, guerilla war tour<br>Yeah sure sure, when push comes to shove<br>It's well-done beef but it's still done love<br><br>Song: In the Streets -- (0.897)", "As if, stance mad stiff<br>Metal Face DOOM, beware, he bear gifts<br>Gab for the shift, overwork, overtime<br>Jerk you been warned, go for mine<br>In the dance hall play the wall like handball<br>Till his pants fall, brawl till last call<br>Loose cannon, squeeze a drip<br>Off to rip this one for the Gipper, get gypped<br>That nig' ya dig don't tip the strippers<br>Foamposite mask, matching slippers<br>Yo where's Starks Backpack of ammo<br>Warriors said let your flags blow, camo<br>These dudes is toys like Wham-O<br>Damn though, chip paint driving on the gravel with the Lambo<br>Blamo<br><br>Song: Ray G
 0.6871508379888268, 0.6716867469879518, 0.5827205882352942, 0.6173913043478261, 0.5970149253731343, 0.6542553191489362, 0.6235011990407674, 0.7727272727272727, 0.6844106463878327, 0.6872037914691943], "text": ["Space Ho's", "Vats of Urine", "Mince Meat", "Crosshairs", "Perfect Hair", "Bada Bing", "El Chupa Nibre", "No Names", "A.T.H.F.", "Basket Case", "Old School", "Benzie Box", "The Mask"], "name": "Doom: The Mouse and the Mask", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.617543859649123, 4.731617647058823, 4.529411764705882, 4.925675675675675, 4.757575757575758], "y": [0.5840163934426229, 0.64, 0.6631205673758865, 0.5943775100401606, 0.5989110707803993], "text": ["Sofa King Remix", "El Chupa Nibre Remix", "Perfect Hair II", "Korn Dogs", "Space Ho's (Madlib Remix)"], "name": "Doom: Occult Hymn EP", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.814465408805032, 4.608391608391608, 4.802158273381295], "y": [0.6186770428015564, 0.5813008130081301, 0.6318181818181818], "text": ["Entrees: Kookies", "Appetizers: One Beer", "Entrees: Kon Karne"], "name": "Doom: MM... Food\t", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.785977859778598, 4.293103448275862], "y": [0.5272373540856031, 0.7837837837837838], "text": ["The Mic", "Who You Think I Am"], "name": "Doom: Operation Doomsday", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.855305466237942, 4.680851063829787], "y": [0.5316239316239316, 0.5356125356125356], "text": ["The Finest", "Hero V.S. Villain"], "name": "Doom: Operation: Doomsday", "mode": "marker ...

# %%
a = 'Rap Ambush'
for c in works['Doom'].songs:
    if c.name == a:
        a = c
print(a.raw_text)
# Out:
# [Intro]
# So we're gonna stand on perimeter
# We did have some shots fired right down the street on us
# while this was goin on, so we gotta set up a tight perimeter
# We got the streets blocked off
# to make sure we don't have any drivebys on us
# Other than that, the operation went, fairly well...
#
# [Doom]
# Who told you that Rolled through, BRRRAT
# Old to the new knows who hold the hat
# Custom tailored fitted, head stayed same size
# Big since first born, well spree to game wise
# Same guys, same disguise, sick aim eye stare
# A thick dame thighs, click claim prize
# And the lucky contestant was sent
# a whole year's supply of buckets of yucky excrement
# Digital format, provide the ROM
# Riot calm, flow was like a roadside bomb
# Flipped the Humvee, impact was limb-numbing
# Cameraman wig back, gunner screaming INCOMING
# RPG, rhyme propelled grenade
# Time to yell, scramble for cover in the shade
# Bright as the midday sun, then it fade
# Darkness come quick, some run and get sprayed
# Rot dead, hot lead, it's rainin
# Left 'em with they brains kicked in with they trainin
# Dragged the remains into the open by the bootstraps
# Dogtag attached to explosive human booby traps
# Where's air support, ears ringin, mortars whistlin
# Bloodshot vision after thought abort mission
# Too little too late, as the last man gushed
# Took no prisoners mushed, rap ambush
#
# {MURDALIZING SUCKER EMCEES~!}

# %%
for d in a.uniq_art_verses:
    print(d.content, d.word_syls, len(d.unique_words), len(d.word_syls))
# Out:
# Who told you that Rolled through, BRRRAT
# Old to the new knows who hold the hat
# Custom tailored fitted, head stayed same size
# Big since first born, well spree to game wise
# Same guys, same disguise, sick aim eye stare
# A thick dame thighs, click claim prize
# And the lucky contestant was sent
# a whole year's supply of buckets of yucky excrement
# Digital format, provide the ROM
# Riot calm, flow was like a roadside bomb
# Flipped the Humvee, impact was limb-numbing
# Cameraman wig back, gunner screaming INCOMING
# RPG, rhyme propelled grenade
# Time to yell, scramble for cover in the shade
# Bright as the midday sun, then it fade
# Darkness come quick, some run and get sprayed
# Rot dead, hot lead, it's rainin
# Left 'em with they brains kicked in with they trainin
# Dragged the remains into the open by the bootstraps
# Dogtag attached to explosive human booby traps
# Where's air support, ears ringin, mortars whistlin
# Bloodshot vision after thought abort mission
# Too little too late, as the last man gushed
# Took no prisoners mushed, rap ambush
#
# {MURDALIZING SUCKER EMCEES~!} {'digital': [['D', 'IH1', 'JH', 'AH0', 'T', 'AH0', 'L'], ['D', 'IH1', 'JH', 'IH0', 'T', 'AH0', 'L']], 'sent': [['S', 'EH1', 'N', 'T']], 'supply': [['S', 'AH0', 'P', 'L', 'AY1']], 'mushed': [['M', 'Y', 'UW1', 'Z', 'D']], 'support': [['S', 'AH0', 'P', 'AO1', 'R', 'T']], 'stare': [['S', 'T', 'EH1', 'R']], 'sick': [['S', 'IH1', 'K']], 'lucky': [['L', 'AH1', 'K', 'IY0']], 'murdalizing': [['M', 'AO1', 'R', 'AH0', 'L', 'AY2', 'Z', 'IH0', 'NG']], 'screaming': [['S', 'K', 'R', 'IY1', 'M', 'IH0', 'NG']], 'old': [['OW1', 'L', 'D']], 'dogtag': [['OW0', 'G', 'AA1', 'T', 'AH0']], 'after': [['AE1', 'F', 'T', 'ER0']], 'spree': [['S', 'P', 'R', 'IY1']], 'humvee': [['HH', 'AH1', 'M', 'V', 'IY2']], 'cover': [['K', 'AH1', 'V', 'ER0']], 'back': [['B', 'AE1', 'K']], 'since': [['S', 'IH1', 'N', 'S']], 'scramble': [['S', 'K', 'R', 'AE1', 'M', 'B', 'AH0', 'L']], 'run': [['R', 'AH1', 'N']], 'big': [['B', 'IH1', 'G']], 'lead': [['L', 'EH1', 'D'], ['L', 'IY1', 'D']], 'late': [['L', 'EY1', 'T']], 'who': [['HH', 'UW1']], 'took': [['T', 'UH1', 'K']], 'claim': [['K', 'L', 'EY1', 'M']], 'to': [['T', 'UW1'], ['T', 'IH0'], ['T', 'AH0']], 'ringin': [['R', 'IH1', 'NG', 'IH0', 'NG']], 'born': [['B', 'AO1', 'R', 'N']], 'same': [['S', 'EY1', 'M']], 'a': [['AH0'], ['EY1']], 'like': [['L', 'AY1', 'K']], 'hold': [['HH', 'OW1', 'L', 'D']], 'flipped': [['F', 'L', 'IH1', 'P', 'T']], 'custom': [['K', 'AH1', 'S', 'T', 'AH0', 'M']], 'tailored': [['T', 'EY1', 'L', 'ER0', 'D']], 'bomb': [['B', 'AA1', 'M'], ['B', 'AO1', 'M']], 'stayed': [['S', 'T', 'EY1', 'D']], 'emcees': [['EH1', 'M', 'S', 'IY1']], 'sprayed': [['S', 'P', 'R', 'EY1', 'D']], 'kicked': [['K', 'IH1', 'K', 'T']], 'yucky': [['Y', 'AH1', 'K', 'IY0']], 'hat': [['HH', 'AE1', 'T']], 'gushed': [['G', 'AH1', 'SH', 'T']], 'air': [['EH1', 'R']], 'explosive': [['IH0',
# %%
d.all_words
# Out:
# ['who',
#  'told',
#  'you',
#  'that',
#  'rolled',
#  'through',
#  'brrrat',
#  'old',
#  'to',
#  'the',
#  'new',
#  'knows',
#  'who',
#  'hold',
#  'the',
#  'hat',
#  'custom',
#  'tailored',
#  'fitted',
#  'head',
#  'stayed',
#  'same',
#  'size',
#  'big',
#  'since',
#  'first',
#  'born',
#  'well',
#  'spree',
#  'to',
#  'game',
#  'wise',
#  'same',
#  'guys',
#  'same',
#  'disguise',
#  'sick',
#  'aim',
#  'eye',
#  'stare',
#  'a',
#  'thick',
#  'dame',
#  'thighs',
#  'click',
#  'claim',
#  'prize',
#  'and',
#  'the',
#  'lucky',
#  'contestant',
#  'was',
#  'sent',
#  'a',
#  'whole',
#  "year's",
#  'supply',
#  'of',
#  'buckets',
#  'of',
#  'yucky',
#  'excrement',
#  'digital',
#  'format',
#  'provide',
#  'the',
#  'rom',
#  'riot',
#  'calm',
#  'flow',
#  'was',
#  'like',
#  'a',
#  'roadside',
#  'bomb',
#  'flipped',
#  'the',
#  'humvee',
#  'impact',
#  'was',
#  'limb-numbing',
#  'cameraman',
#  'wig',
#  'back',
#  'gunner',
#  'screaming',
#  'incoming',
#  'rpg',
#  'rhyme',
#  'propelled',
#  'grenade',
#  'time',
#  'to',
#  'yell',
#  'scramble',
#  'for',
#  'cover',
#  'in',
#  'the',
#  'shade',
#  'bright',
#  'as',
#  'the',
#  'midday',
#  'sun',
#  'then',
#  'it',
#  'fade',
#  'darkness',
#  'come',
#  'quick',
#  'some',
#  'run',
#  'and',
#  'get',
#  'sprayed',
#  'rot',
#  'dead',
#  'hot',
#  'lead',
#  "it's",
#  'rainin',
#  'left',
#  "'em",
#  'with',
#  'they',
#  'brains',
#  'kicked',
#  'in',
#  'with',
#  'they',
#  'trainin',
#  'dragged',
#  'the',
#  'remains',
#  'into',
#  'the',
#  'open',
#  'by',
#  'the',
#  'bootstraps',
#  'dogtag',
#  'attached',
#  'to',
#  'explosive',
#  'human',
#  'booby',
#  'traps',
#  "where's",
#  'air',
#  'support',
#  'ears',
#  'ringin',
#  'mortars',
#  'whistlin',
#  'bloodshot',
#  'vision',
#  'after',
#  'thought',
#  'abort',
#  'mission',
#  'too',
#  'little',
#  'too',
#  'late',
#  'as',
#  'the',
#  'last',
#  'man',
#  'gushed',
#  'took',
#  'no',
#  'prisoners',
#  'mushed',
#  'rap',
#  'ambush',
#  'murdalizing',
#  'sucker',
#  'emcees']

# %%
print("\x1b[31m\"red\"\x1b[0m dog")
# Out:
# "red" dog

# %% [markdown]
# what you did
# built CMU pronouncing dict into system by creating dictionary of all words in Rap DB to a sylabule value (or list of vals)
# saved as pickle, can't load everytime as it takes a ton of time to build
# also build into words method a new attribute for verses that is dict of word to sylabl
# built scatter plot viz, made a few ad hoc changes
# fixed slight error in rap clean, need to re run artists
# consider loosening filter for uniq_art_verse,up to you
# made changes to regex for [
#
# what's next
# keep modeling and coming up with stuff!

# %%
#estconn.close()
