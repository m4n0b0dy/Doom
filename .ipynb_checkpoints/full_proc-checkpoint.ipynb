# %%
import RAP_MASTER_LIB
#MY LIBRARIES -- towards the end of project/when you need a break write up documentaiton of libraries
#another library for plotting and testing
from rap_scrpr import *
from rap_db import *
from rap_clean import*
from rap_viz import *
from random import shuffle

#estconn = pg2.connect(database='rap_songs', user='keenan', host='localhost', password='keenan')
#import nltk
#nltk.download()
#create_music_tables(estconn)

# %%
#new_artists = scrape_multi_artists(estconn, ['10sion'])
#create_music_tables(estconn, bypass = True)
#bulk_load(estconn, new_artists)
#lst = ['Del', 'Eminem', 'Jay-Z', 'Chance', '50_Cent', 'Doom']
#l2 = ['Doom']
#works_pull = dict(zip(lst, construct_artists(estconn, art_list = lst)))
#art_save(works_pull)

# %%
lst = ['Del', 'Eminem', 'Jay-Z', 'Chance', '50_Cent', 'Doom']
works = art_load(lst)

# %%
sub_works = {'Del':works['Del'], 'Chance':works['Chance'], 'Doom':works['Doom']}

# %%
vs = unique_verses_bar(sub_works.values())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="3fd7dfb3-3781-4398-865b-0267b25350a9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3fd7dfb3-3781-4398-865b-0267b25350a9", [{"type": "bar", "x": [95, 113, 54, 18, 115, 65, 53, 16, 19, 12], "orientation": "h", "text": ["How did it happen An independent corporation<br>With no control could maintain it<br>With rebellious force, developed a course of action<br>We advertise, inviting all to court, the massive<br>A queen's faithful hand, maidens born to wealthy parents<br>A life of luxury, but full of scorn, yeah, they be jealous<br>We were omnivores, gathered food with our tongues<br>Peaceful, unprepared against the guns<br>Ever since we was young they slayed our real master<br>Now I'm told, blast the rifles to peel back domes<br>Heavy weapon power sources for confrontation<br>Against hot situations, safe world's invaded<br>Song: Do You Remember? -- (0.832)", "The humanoid race feels that they should rule the whole space-time continuum<br>Decimating villages<br>Deltron, the hero of alliance is sent forth<br>To insure chief aids don't catch a heat ray<br>I just scoped this fiber rope<br>It looks like a good conductor of electricity<br>Use it for a stun net for anyone stepping in the vicinity<br>Living within the walls of our buildings<br>Impervious surface, industrial strength<br>Heavy-duty shield generators for hater attempts<br>Metallic content within the star ship<br>Computer system shoots us through parsecs<br>Light years, astronomical units<br>NASA couldn't fathom the havoc they producing<br>Measured in fractions involving objects from a single star system but yet so complex<br>Song: Talent Supercedes -- (0.832)", "A hundred and fourteen and more fiend<br>Proportion, black mortality casualty<br>Gradually losin grips with reality<br>When a child's view in violence so casually<br>Callously, carousel of confusion<br>Only comes to a halt with thoughtful conclusions<br>I'ma weigh the pros and cons of what's goin on<br>Decide whether to go beyond and go along<br>Song: What's Wrong with This Picture -- (0.833)", " <br>\"You trippin' man.\"<br>\"Man I be grindin' and chillin'<br> Nigga, I was rolling dice the other day nigga.\" <br>Song: Followers * -- (0.833)", "Yo, avoiding the corporate sector running with the rebel operatives<br>Pulling a dark saber out on hostages<br>Deltron O from the under city wonders will they never cease<br>Fear of black planet, serious heat<br>Here in the street high doubts and strongholds<br>Action adventures go beyond the globe<br>The lost ones mobbing in repulsive trucks<br>Transporting troops and not for sport<br>My measurement systems are pleasant for list
"mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [5.137254901960785], "y": [0.8031496062992126], "text": ["Strange Universe"], "name": "Del: Strange Journey Volume Three", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [5.141447368421052], "y": [0.5259515570934256], "text": ["The Repo Man Sings for You"], "name": "Del: Steal This Album", "mode": "markers", "hoverinfo":  ...

# %%
#functions used by classes
def flatten(container):
    for i in container:
        if isinstance(i, (list,tuple)):
            for j in flatten(i):
                yield j
        else:
            yield i
#spaced
#like this, can edit and imporve, need to change opacity or get rid of black, prob both
def make_color_dic(all_vs):
    max_value = 16581375 #255**3
    interval = int(max_value / len(all_vs))
    colors = [hex(I)[2:].zfill(6) for I in range(0, max_value, interval)]
    return dict(zip(all_vs, [(int(i[:2], 16), int(i[2:4], 16), int(i[4:], 16)) for i in colors]))
#lowkey becoming as complex as my verse, song, album, artist classes

# %%
#complex class, but worth it, very powerful (aka kinda slow but badass)
#-made this more complex and even stronger, yet more rhobuse lol. labeled a lot so I wouldn't lose myself
class word():
    def __init__(self, text):
        #clean and find the nearest word
        #may have to address
        text = re.sub("'",'', text)
        #no need to waste time with numbers, can make seperate class if need be
        if text.isdigit():
            self.found_text, self.all_vowel_sounds, self.matches = None, ['unk'], list(zip([text], ['unk']))
            return None
        self.found_text = text
        
        if text not in CMU_KEYS:
            found_word = get_close_matches(text, CMU_KEYS)
            if not found_word:
                print('Error with '+text)
                self.found_text, self.all_vowel_sounds, self.matches = None, ['unk'], list(zip([text], ['unk']))
                return None
            self.found_text = found_word[0]
            
        #using that regex, pull all vowels from word from cmu dict. Pull all vowels for testing later
        #I think this is too much effort for low payoff, I'd have to totally redo the sylbl matching too 
        #just try it
        self.all_vowel_sounds = []
        for mtch in CMU_DICT[self.found_text]:
            self.all_vowel_sounds.append(list(filter(re.compile(r'[aeiou]+', re.IGNORECASE).match, mtch)))
        #assuming it's the first CMU match here
        self.vowel_sounds = list(filter(re.compile(r'[aeiou]+', re.IGNORECASE).match, CMU_DICT[self.found_text][0]))
        
        #now to segment words based on sylabule, first try PYPHEN
        self.sylbl_sounds = PYPHEN_DIC.inserted(self.found_text).split('-')
        #if they aren't equal try my own splitting
        if len(self.vowel_sounds)!=len(self.sylbl_sounds):
            word.my_split(self, self.found_text)
        word.sylbl_match(self)
            
    #these next parts are my guesses at segmented, throwing shit and seeing if it sticks    
    def my_split(self, text_to_split, ap='', ap_num=False):
        #if we haven't found the right sylb count, loop until we find a match or vowels min below 0
        vowels = 4
        sylbl_sound_try = []
        while len(self.vowel_sounds)!=len(sylbl_sound_try) and vowels>0:
            #test by segmented words on {,4} sylbs, then {,3}, then {,2}, then {,1}, %%% is for my special cases which come later
            sylbl_sound_try = re.findall(r'(%%%|[^aeiouy%]*[aeiouy]{,'+str(vowels)+'}[^aeiouy%]*)', text_to_split, re.IGNORECASE)
            sylbl_sound_try = list(filter(None, sylbl_sound_try))
            vowels-=1

        #this is for my edge cases
        #for 0 sylbl spec cases, add our 0 sylbl
        if ap_num == 0 and ap != '':
            found = sylbl_sound_try.index('%%%')
            #if it's the first sylbl
            if found == 0:
                sylbl_sound_try[1] = ap+sylbl_sound_try[1]
            #otherwise add to previous sylbl
            else:
                sylbl_sound_try[found-1] = sylbl_sound_try[found-1]+ap
            sylbl_sound_try.remove('%%%')
            
        #for 1 sylbl spec cases - get's it's own sylbl
        elif ap_num == 1 and ap != '':
            sylbl_sound_try = [ap if mtch=='%%%' else mtch for mtch in sylbl_sound_try]
            
        #check again if we found the match
        if len(self.vowel_sounds)==len(sylbl_sound_try):
            self.sylbl_sounds = sylbl_sound_try
            return
        
        #this signifies it's our first time throuh my_split
        #a little fancy recursion cause fuck it
        elif not ap_num and ap == '':
            reg_exs = {#this is for silent edge cases (de, te, le, ey, plurals, past tense) at the end of word
                        r'.*?(e[sd]|[^aeiouy][ey])$':0,
                        #this is for 1 sylbl edge cases anywhere in word
                        r'.*?([^aeiouy]*eve)*.*':1,
                        #this is for 1 sylbl edge cases at the end of a word
                        r'.*?(tion*)$':1}
            for reg_ex, sylbl_count in reg_exs.items():
                word.spec_split(self, reg_ex, sylbl_count)
                #check again if succesful, the assignment happens in my_split
                if len(self.vowel_sounds)==len(self.sylbl_sounds):
                    break
        #if we've gotten here, it wasn't succesful
        return
        
    #this func is to deal with specific edge cases at by capturing and extracting in regex (???) and then running my split
    def spec_split(self, regex_end, ap_syls):
        matched = re.match(regex_end, self.found_text, re.IGNORECASE)
        if matched:
            if matched.group(1):
                matched = matched.group(1)
                rep_matched = self.found_text.replace(matched,'%%%')
                word.my_split(self, rep_matched, matched, ap_syls)
                
    #this function matches sylbl to word text for colorizing
    #takes some guesses if they are unequal in size (rare but possible)
    #^for now just not gonna color, unfortunate, but there isn't a clean solve yet - maybe exceptions
    def sylbl_match(self):
        #just gonna gray out for now, come back later
        self.matches = list(zip(self.sylbl_sounds, ['unk']*len(self.sylbl_sounds)))
        #if we know then obvi assign
        if len(self.sylbl_sounds) == len(self.vowel_sounds):
            self.matches = list(zip(self.sylbl_sounds, self.vowel_sounds))

# %%
class line():
    def __init__(self, raw_text):
        words = re.sub("[^0-9a-zA-Z\']+", ' ', raw_text)
        self.words = list(filter(None, words.split(' ')))
        self.word_objs = []
        for wrd in self.words:
            cur_wrd = word(wrd.lower())
            self.word_objs.append(cur_wrd)
        line.make_line_attr(self)
        
    #breaking this up into two for loops so I can re run make_line_attr
    def make_line_attr(self):
        self.vowel_sounds = []
        self.all_cmu_vowel_sounds = []
        self.word_to_vowels = []
        for cur_wrd in self.word_objs:
            #might not need this
            self.vowel_sounds.extend(list(zip(*cur_wrd.matches))[1])
            #this is for the viz
            self.word_to_vowels.append(cur_wrd.matches)            
            #this will be used in optimization later
            self.all_cmu_vowel_sounds.extend(flatten(cur_wrd.all_vowel_sounds))

# %%
class verse_graph():
    def __init__(self, verse_obj):
        #load in everything and no function running yet I think
        self.ver_as_lines = []
        for line_obj in verse_obj.all_lines:
            cur_line = line(line_obj)
            self.ver_as_lines.append(cur_line)
            
    #no time to test, works well so far but needs good testing
    #not sure if this will even help but wanted to include it
    #will probably take some time
    #WOWOWOWOWOWOWOW ACTUALLY MAKING MAJOR CHANGES IT SEEMS, FUCK YEAH
    #needs to be tested a little more, checked, and pruned for uncessary shit, surprisingly fast
    def opto_matches(self, pop=False):
        #cant assign variables in def using self??
        if not pop:
            pop=int(len(self.ver_as_lines)/2)
        optimized_lines = []
        for dex, line_obj in enumerate(self.ver_as_lines):
            nearby_lines = self.ver_as_lines[max(0,dex-pop):dex+pop]
            all_nearby_vowels = []
            for nearby_line in nearby_lines:
                all_nearby_vowels.extend(nearby_line.all_cmu_vowel_sounds)
            count_nearby_vowels = dict(Counter(all_nearby_vowels))
            
            new_word_objs=[]
            #print(count_nearby_vowels)
            for wrd in line_obj.word_objs:
                if len(wrd.all_vowel_sounds)>1 and 'unk' not in wrd.all_vowel_sounds:
                    final_config = wrd.matches
                    for sylbl_config in wrd.all_vowel_sounds:
                        #only works if it's the same count of sylbs as current
                        if len(sylbl_config) == len(wrd.vowel_sounds):
                            new_config=[]
                            for test, current, sylbl in zip(sylbl_config, list(zip(*final_config))[1], wrd.sylbl_sounds):
                                if count_nearby_vowels[test] > count_nearby_vowels[current]:
                                    new_config.append((sylbl, test))
                                    #temporary
                                    #print('changed',current,'to',test,'for',sylbl)
                                    #print(count_nearby_vowels[test], count_nearby_vowels[current])
                                else:
                                    new_config.append((sylbl, current))
                                    #print('kept',current,'the same')
                            final_config = new_config
                    #change the vowel sound of core word -  for consistency
                    wrd.vowel_sounds = list(zip(*final_config))[1]
                    #and of course the matches, can change by running match or setting equal, with that, the word is totally remade
                    wrd.matches = final_config
                    
                #new words for each line
                new_word_objs.append(wrd)
                
            #set the lines word objects equal to our new words
            line_obj.word_objs = new_word_objs
            #remake the line attributes with this new word list
            line_obj.make_line_attr()
            optimized_lines.append(line_obj)
        #finally remake our verse lines with updated attributes
        self.ver_as_lines = optimized_lines
        
    #pretty straightforward
    def colorize_vowels(self, match_type='exact'):
        vowels_used = set()
        all_vowels = set(flatten([line_obj.vowel_sounds for line_obj in self.ver_as_lines]))-{'unk'}
        if match_type=='near':
            vowels_used = set([all_v[:-1] for all_v in all_vowels])
        elif match_type=='broad':
            vowels_used = set([all_v[0] for all_v in all_vowels])
        else:
            vowels_used = all_vowels
        self.vowel_colors = make_color_dic(vowels_used)
    
    def make_colored_verse(self):
        return

# %%
one = verse_graph(works['Del'].uniq_art_verses[0])

# %%
one.opto_matches()
one.colorize_vowels('near')
one.vowel_colors
# Out:
# {'AA': (198, 203, 117),
#  'AE': (108, 110, 250),
#  'AH': (72, 73, 252),
#  'AO': (0, 0, 0),
#  'AW': (180, 184, 246),
#  'AY': (126, 129, 121),
#  'EH': (54, 55, 125),
#  'ER': (90, 92, 123),
#  'EY': (18, 18, 127),
#  'IH': (216, 221, 244),
#  'IY': (144, 147, 248),
#  'OW': (234, 240, 115),
#  'UH': (36, 36, 254),
#  'UW': (162, 166, 119)}

# %%
for l in one.ver_as_lines:
    #print(l.vowel_sounds)
    print(l.vowel_sounds)
    print()
#one.ver_as_lines[0].__dict__
# Out:
# ['AY1', 'AA1', 'UW1', 'IH0', 'EH1', 'AH0', 'AH0', 'UW1', 'ER0', 'AY1', 'AH0']
#
# ['EH1', 'ER0', 'AY1', 'AA1', 'AE1', 'AE1', 'OW1', 'AH1']
#
# ['IH1', 'IH1', 'unk', 'AH0', 'AY1', 'AH1', 'OW1', 'AH0', 'UW2', 'AH0', 'AH0', 'EY1', 'AH0']
#
# ['EY1', 'AY1', 'UW1', 'EY1', 'ER1', 'AH0', 'AH0']
#
# ['ER1', 'EH1', 'AO1', 'EY1', 'UW1', 'IH1', 'AH0', 'AH0']
#
# ['ER1', 'AA2', 'AH0', 'IH1', 'AH0', 'IH1', 'IY1', 'ER0', 'AH0', 'EH1', 'IY1', 'ER2']
#
# ['EH1', 'IY1', 'AY1', 'AH0', 'AY1', 'IY1', 'IH0', 'AA1']
#
# ['IY0', 'AE1', 'AH0', 'EY2', 'EH1', 'AE1', 'IH0', 'IY1', 'ER0', 'EY1', 'AH0', 'AE1', 'AH0', 'IY1', 'ER0']
#
# ['EH1', 'IY0', 'AA2', 'IY0', 'UW1', 'AH0', 'AO1', 'EH1', 'AO1', 'AE1', 'UH1']
#
# ['IY1', 'IH0', 'EY1', 'EY1', 'AH0', 'AA1', 'AE1', 'IH0', 'AH0', 'AA1', 'AY1']
#
# ['IY1', 'IY2', 'ER0', 'IY1', 'UW1', 'EY1', 'AW1', 'ER0', 'AE1', 'UH2']
#
# ['IH1', 'IH0', 'AH1', 'IH0', 'AH0', 'AO1', 'AH1', 'OW1', 'AH0', 'AH0', 'AA1', 'AY2']
#
# ['EH1', 'OW0', 'AA1', 'AE1', 'AH1', 'IH1', 'AE1', 'AH1']
#
# ['IH0', 'OW1', 'IH0', 'AH0', 'ER1', 'AW1', 'IH1', 'IH0', 'AO1', 'AH0', 'EY1', 'UW1', 'AH0']
#
# ['AH0', 'AE1', 'AH1', 'AO1', 'ER0', 'AW1', 'AY1', 'AE1', 'AH1']
#
# ['EH1', 'IY0', 'UW1', 'AH0', 'IH1', 'AH0', 'EY2', 'AH0', 'EY1', 'AH0', 'EY2', 'AO1', 'EY1', 'UW1', 'EH1']
#
# ['UW1', 'AH0', 'AY1', 'AH1', 'IH0', 'AH0', 'AH1', 'AH0', 'EY1']
#
# ['AE1', 'AH0', 'AH1', 'AH0', 'AE1', 'AO1', 'EY2', 'IH1', 'AH1', 'ER0', 'AH1']
#
# ['UW1', 'ER1', 'AE1', 'IH0', 'AH1', 'AH0', 'IH0', 'AH1', 'AH0', 'EY1']
#
# ['OW1', 'IH1', 'AY1', 'UW1', 'EH1', 'AH0', 'IH1', 'UW1', 'AH1', 'ER0', 'AH1']
#
# ['UW1', 'AO1', 'AE1', 'IY1', 'AY1']
#
# ['UW1', 'IH0', 'EH1', 'AW1', 'ER0', 'AO1', 'IY0', 'AH0', 'EH1', 'AY0', 'ER0', 'AW1', 'UW1', 'AH0', 'AA1']
#
# ['OW1', 'IY0', 'UW1', 'IY1', 'AY1', 'AE1']
#
# ['AY1', 'AA1', 'AH0', 'IH0', 'AY1', 'AH0', 'AY1', 'AH0']
#
# ['UW1', 'IH1', 'AY1', 'EY1', 'UW1', 'AO1', 'IH0', 'AY1', 'AH0', 'AH0']
#
# ['AH1', 'AO1', 'AO2', 'ER0', 'EY1', 'AH0', 'IH1', 'AH0', 'AY1', 'AH1']
#
# ['AE1', 'AO1', 'OW1', 'AH0', 'UW1', 'ER0', 'IH1', 'AH0', 'AH0', 'IH0', 'ER1', 'UW1', 'UW1', 'EY1', 'ER0']

# %%
#one.ver_as_lines[0].__dict__
one.opto_vowels()

# %%
for l in one.ver_as_lines:
    #print(l.vowel_sounds)
    print(l.vowel_sounds)
    print()
#one.ver_as_lines[0].__dict__
# Out:
# ['AY1', 'AA1', 'AH0', 'IH0', 'EH1', 'AH0', 'AH0', 'UW1', 'ER0', 'AY1', 'AH0']
#
# ['EH1', 'ER0', 'AY1', 'AA1', 'AH0', 'AH0', 'OW1', 'AH1']
#
# ['IH0', 'IH0', 'unk', 'AH0', 'AY1', 'AH0', 'OW1', 'AH0', 'UW2', 'AH0', 'AH0', 'EY1', 'AH0']
#
# ['EY1', 'AY1', 'UW1', 'EY1', 'ER1', 'AH0', 'AH0']
#
# ['ER1', 'EH1', 'AO1', 'EY1', 'AH0', 'IH1', 'AH0', 'AH0']
#
# ['ER1', 'AA2', 'AH0', 'IH1', 'AH0', 'IH0', 'IY1', 'ER0', 'AH0', 'EH1', 'IY1', 'ER2']
#
# ['EH1', 'IY1', 'AY1', 'AH0', 'AY1', 'IY1', 'IH0', 'AA1']
#
# ['IY0', 'AE1', 'AH0', 'EY2', 'EH1', 'AE1', 'IH0', 'IY1', 'ER0', 'EY1', 'AH0', 'AE1', 'AH0', 'IY1', 'ER0']
#
# ['EH1', 'IY0', 'AA2', 'IY0', 'UW1', 'AH0', 'AO1', 'IH1', 'AO1', 'AE1', 'UH1']
#
# ['IY1', 'IH0', 'EY1', 'EY1', 'AH0', 'ER0', 'AE1', 'IH0', 'AH0', 'AA1', 'AY1']
#
# ['IY1', 'IY2', 'ER0', 'IY1', 'AH0', 'EY1', 'AW1', 'ER0', 'AE1', 'UH2']
#
# ['IH1', 'IH0', 'AH1', 'IH0', 'AH0', 'AO1', 'AH0', 'OW1', 'AH0', 'AH0', 'AA1', 'AY2']
#
# ['EH1', 'OW0', 'ER0', 'AE1', 'AH1', 'IH0', 'AE1', 'AH1']
#
# ['IH0', 'OW1', 'IH0', 'AH0', 'ER1', 'AW1', 'IH1', 'IH0', 'AO1', 'AH0', 'EY1', 'UW1', 'AH0']
#
# ['AH0', 'AE1', 'AH1', 'AO1', 'ER0', 'AW1', 'AY1', 'AE1', 'AH1']
#
# ['EH1', 'IY0', 'AH0', 'AH0', 'IH1', 'AH0', 'EY2', 'AH0', 'AE1', 'AH0', 'EY2', 'ER0', 'EY1', 'UW1', 'EH1']
#
# ['UW1', 'AH0', 'AY1', 'AH1', 'IH0', 'AH0', 'AH1', 'AH0', 'EY1']
#
# ['AE1', 'AH0', 'AH1', 'AH0', 'AH0', 'AO1', 'IY0', 'AH0', 'AH1', 'ER0', 'AH1']
#
# ['UW1', 'ER1', 'AH0', 'IH0', 'AH1', 'AH0', 'IH0', 'AH1', 'AH0', 'EY1']
#
# ['OW1', 'IH0', 'AY1', 'AH0', 'EH1', 'AH0', 'IH1', 'AH0', 'AH1', 'ER0', 'AH1']
#
# ['UW1', 'AO1', 'AE1', 'IY1', 'AY1']
#
# ['AH0', 'IH0', 'EH1', 'AW1', 'ER0', 'AO1', 'IY0', 'AH0', 'EH1', 'AY0', 'ER0', 'AW1', 'AH0', 'AH0', 'AA1']
#
# ['OW1', 'IY0', 'AH0', 'IY0', 'AY1', 'AE1']
#
# ['AY1', 'AA1', 'AH0', 'IH0', 'AY1', 'AH0', 'AY1', 'AH0']
#
# ['AH0', 'IH1', 'AY1', 'EY1', 'AH0', 'AO1', 'IH0', 'AY1', 'AH0', 'AH0']
#
# ['AH1', 'AO1', 'AO2', 'ER0', 'EY1', 'AH0', 'IH0', 'AH0', 'AY1', 'AH1']
#
# ['AE1', 'AO1', 'OW1', 'AH0', 'UW1', 'ER0', 'IH1', 'AH0', 'AH0', 'IH0', 'ER1', 'UW1', 'AH0', 'EY1', 'ER0']

# %%
#use these to test
test = 0
test2 = 0
for a in CMU_KEYS:
    zs = CMU_DICT[a]
    if len(zs) > 1:
        zes = []
        for z in zs:
            zes.append(list(filter(re.compile(r'[aeiou]+', re.IGNORECASE).match, z)))
        it = iter(zes)
        the_len = len(next(it))
        if not all(len(l) == the_len for l in it):
            print(a, zes)
            test+=1
        test2 += 1
        print(a, zes)
    if test == 10 or test2 == 100:
        break
# Out:
# warkentin [['AO0', 'EH1', 'IH0'], ['AO1', 'AH0', 'IH0']]
# weisenborn [['AY1', 'IH0', 'ER0'], ['AY1', 'IH0', 'ER0']]
# reports [['IH0', 'AO1'], ['IY0', 'AO1']]
# eugene [['UW0', 'IY1'], ['UW1', 'IY0']]
# saboteurs [['AE2', 'AH0', 'ER1'], ['AE2', 'IH0', 'AO1']]
# stabilizes [['EY1', 'AH0', 'AY2', 'AH0'], ['EY1', 'AH0', 'AY2', 'IH0']]
# surveys [['ER0', 'EY1'], ['ER1', 'EY2']]
# educator [['EH1', 'AH0', 'EY2', 'ER0'], ['EH1', 'UW0', 'EY2', 'ER0']]
# ourself [['AW0', 'ER0', 'EH1'], ['AA0', 'EH1']]
# ourself [['AW0', 'ER0', 'EH1'], ['AA0', 'EH1']]
# affiliates [['AH0', 'IH1', 'IY0', 'AH0'], ['AH0', 'IH1', 'IY0', 'EY2']]
# zucker [['AH1', 'ER0'], ['UW1', 'ER0']]
# entertaining [['EH2', 'ER0', 'EY1', 'IH0'], ['EH2', 'ER0', 'EY1', 'IH0']]
# granite [['AE1', 'AH0'], ['AE1', 'IH0']]
# katzenstein [['AE1', 'AH0', 'AY0'], ['AE1', 'AH0', 'IY0']]
# bache's [['AE1', 'IH0'], ['EY1', 'IH0']]
# entertains [['EH2', 'ER0', 'EY1'], ['EH2', 'ER0', 'EY1']]
# switches [['IH1', 'AH0'], ['IH1', 'IH0']]
# streisand [['AY1', 'AH0'], ['AY1', 'AE2']]
# muses [['UW1', 'AH0'], ['UW1', 'IH0']]
# preference [['EH1', 'ER0', 'AH0'], ['EH1', 'AH0']]
# preference [['EH1', 'ER0', 'AH0'], ['EH1', 'AH0']]
# colorado's [['AA2', 'ER0', 'AA1', 'OW0'], ['AA2', 'ER0', 'AE1', 'OW0']]
# hudler [['UW1', 'AH0', 'ER0'], ['UW1', 'ER0']]
# hudler [['UW1', 'AH0', 'ER0'], ['UW1', 'ER0']]
# edival [['EH0', 'IY1', 'AH0'], ['EH1', 'IY0', 'AE2']]
# get [['EH1'], ['IH1']]
# hesler [['EH1', 'AH0', 'ER0'], ['EH1', 'ER0']]
# hesler [['EH1', 'AH0', 'ER0'], ['EH1', 'ER0']]
# difabio [['IH0', 'EY1', 'IY0', 'OW0'], ['IH0', 'AE1', 'IY0', 'OW0']]
# mayfield [['EY1', 'IY2'], ['EY1', 'IH0']]
# defended [['IH0', 'EH1', 'AH0'], ['IH0', 'EH1', 'IH0']]
# bowels [['AW1', 'AH0'], ['AW1']]
# bowels [['AW1', 'AH0'], ['AW1']]
# if [['IH1'], ['IH0']]
# rigler [['AY1', 'AH0', 'ER0'], ['IH1', 'ER0']]
# rigler [['AY1', 'AH0', 'ER0'], ['IH1', 'ER0']]
# faces [['EY1', 'AH0'], ['EY1', 'IH0']]
# soviet [['OW1', 'IY0', 'AH0'], ['OW1', 'IY0', 'EH2']]
# basayev [['AE1', 'AA0', 'EH2'], ['AE1', 'AA0', 'EH2']]
# hampshire [['AE1', 'ER0'], ['AE1', 'ER0'], ['AE1', 'AY0', 'ER0'], ['AE1', 'AY0', 'ER0']]
# hampshire [['AE1', 'ER0'], ['AE1', 'ER0'], ['AE1', 'AY0', 'ER0'], ['AE1', 'AY0', 'ER0']]
# hukill [['UW1', 'IH0'], ['UW1', 'IH0']]
# naturalize [['AE1', 'ER0', 'AH0', 'AY2'], ['AE1', 'AH0', 'AY2']]
# naturalize [['AE1', 'ER0', 'AH0', 'AY2'], ['AE1', 'AH0', 'AY2']]
# shorenstein [['AO1', 'AH0', 'IY0'], ['AO1', 'AH0', 'AY0']]
# travelers [['AE1', 'AH0', 'ER0'], ['AE1', 'ER0']]
# travelers [['AE1', 'AH0', 'ER0'], ['AE1', 'ER0']]
# diversification [['AY0', 'ER2', 'AH0', 'AH0', 'EY1', 'AH0'], ['IH0', 'ER2', 'AH0', 'AH0', 'EY1', 'AH0']]
# presses [['EH1', 'AH0'], ['EH1', 'IH0']]
# sandos [['AE1', 'OW0'], ['AE1', 'OW0']]
# komodo [['AH0', 'OW1', 'OW0'], ['OW0', 'OW1', 'OW0']]
# murray [['ER1', 'IY0'], ['AH1', 'IY0']]
# investments' [['IH0', 'EH1', 'AH0'], ['IH0', 'EH1', 'AH0']]
# versus [['ER1', 'AH0'], ['ER1', 'AH0']]
# regulated [['EH1', 'AH0', 'EY2', 'AH0'], ['EH1', 'AH0', 'EY2', 'IH0']]
# diverted [['AY0', 'ER1', 'IH0'], ['IH0', 'ER1', 'IH0']]
# which's [['IH1', 'IH0'], ['IH1', 'IH0']]
# chartists [['AA1', 'IH0'], ['AA1', 'IH0'], ['AA1', 'IH0']]
# began [['IH0', 'AE1'], ['IY0', 'AE1']]
# taxidermists [['AE1', 'AH0', 'ER2', 'AH0'], ['AE1', 'AH0', 'ER2', 'AH0']]
# desperately [['EH1', 'ER0', 'AH0', 'IY0'], ['EH1', 'AH0', 'IY0']]
# desperately [['EH1', 'ER0', 'AH0', 'IY0'], ['EH1', 'AH0', 'IY0']]

# %% [markdown]
# Here's a little guide in case you forget. To add an excption just add what you want to captur to whatever type under reg_exs. So far only 3 types, silent suffixes, 1 sylbl mid words, 1 sylbl suffixes, just add your word and a | and you're golden.

# %% [markdown]
# Just some of the exceptions
# {'austria': (3, ['aus', 'tria']),
#  'creations': (3, ['cre', 'ations']),
#  'equestrian': (4, ['eques', 'tri', 'an']),
#  'equivalence': (4, ['equiv', 'a', 'lence']),
#  'fumbling': (3, ['fum', 'bling']),
#  'imm': (3, ['imm']),
#  "it'll": (2, ["it'll"]),
#  'opera': (2, ['opera']),
#  'ruffling': (3, ['ruf', 'fling']),
#  'simpler': (3, ['sim', 'pler']),
#  'societies': (4, ['so', 'ci', 'eties']),
#  'struggling': (3, ['strug', 'gling']),
#  'stumbling': (3, ['stum', 'bling']),
#  "that'll": (2, ["that'll"]),
#  'unique': (2, ['unique']),
#  'unsettling': (4, ['un', 'set', 'tling']),
#  'visualize': (3, ['vi', 'su', 'al', 'ize'])}

# %%
#https://programminghistorian.org/en/lessons/creating-and-viewing-html-files-with-python
#import webbrowser
#webbrowser.open_new('python.org')

#https://stackoverflow.com/questions/26462893/import-html-to-ipython-notebook-file
#https://stackoverflow.com/questions/25698448/how-to-embed-html-into-ipython-output
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
#this is all the vowel sounds
alls = set()
for v in CMU_DICT.values():
    for z in v[0]:
        if re.match(r'.*[aeiou].*',z, re.IGNORECASE):
            alls = alls|{z}
# Out:
# <h1>Hello, world!</h1>

# %%
alls
# Out:
# {'AA0',
#  'AA1',
#  'AA2',
#  'AE0',
#  'AE1',
#  'AE2',
#  'AH0',
#  'AH1',
#  'AH2',
#  'AO0',
#  'AO1',
#  'AO2',
#  'AW0',
#  'AW1',
#  'AW2',
#  'AY0',
#  'AY1',
#  'AY2',
#  'EH0',
#  'EH1',
#  'EH2',
#  'ER0',
#  'ER1',
#  'ER2',
#  'EY0',
#  'EY1',
#  'EY2',
#  'IH0',
#  'IH1',
#  'IH2',
#  'IY0',
#  'IY1',
#  'IY2',
#  'OW0',
#  'OW1',
#  'OW2',
#  'OY0',
#  'OY1',
#  'OY2',
#  'UH0',
#  'UH1',
#  'UH2',
#  'UW0',
#  'UW1',
#  'UW2'}

# %%
#spaced
#like this, can edit and imporve, need to change opacity or get rid of black, prob both
def make_color_dic(all_vs):
    max_value = 16581375 #255**3
    interval = int(max_value / len(all_vs))
    colors = [hex(I)[2:].zfill(6) for I in range(0, max_value, interval)]
    return dict(zip(all_vs, [(int(i[:2], 16), int(i[2:4], 16), int(i[4:], 16)) for i in colors]))

a = make_color_dic(alls)

# %%
#fully random
import random
r = lambda: random.randint(0,255)
print('#%02X%02X%02X' % (r(),r(),r()))
# Out:
# #ED5E4E

# %%
# Out:
# [(0, 0, 0),
#  (5, 159, 91),
#  (11, 62, 182),
#  (16, 222, 17),
#  (22, 125, 108),
#  (28, 28, 199),
#  (33, 188, 34),
#  (39, 91, 125),
#  (44, 250, 216),
#  (50, 154, 51),
#  (56, 57, 142),
#  (61, 216, 233),
#  (67, 120, 68),
#  (73, 23, 159),
#  (78, 182, 250),
#  (84, 86, 85),
#  (89, 245, 176),
#  (95, 149, 11),
#  (101, 52, 102),
#  (106, 211, 193),
#  (112, 115, 28),
#  (118, 18, 119),
#  (123, 177, 210),
#  (129, 81, 45),
#  (134, 240, 136),
#  (140, 143, 227),
#  (146, 47, 62),
#  (151, 206, 153),
#  (157, 109, 244),
#  (163, 13, 79),
#  (168, 172, 170),
#  (174, 76, 5),
#  (179, 235, 96),
#  (185, 138, 187),
#  (191, 42, 22),
#  (196, 201, 113),
#  (202, 104, 204),
#  (208, 8, 39),
#  (213, 167, 130),
#  (219, 70, 221),
#  (224, 230, 56),
#  (230, 133, 147),
#  (236, 36, 238),
#  (241, 196, 73),
#  (247, 99, 164)]

# %% [markdown]
# what you did
# made matches into word that has word segs to vowel soudns for viz
# built very first verse graph object draft. It has lines, with words and their associated vowel sounds
# ALSO BUILT OPTO, IT LOOKS WITHIN A SPECIFIED SURRONDING POPULATION OF EACH LINE AND FOES THROUGH EACH WORD OF EACH LINE AND PICKS THE MOST POPULAR VOWEL SOUND TO INCREASE OVERALL SIMILARRIY -DOPPPPE \
# Tested at work, wasn't making changes but set code to remake lines and set equal
#
# what's next
# build out verse_graph with matching/colorizing (could do seperately or the same time)
# before near match stuff or exceptions dic, let's build viz, then see into this stuff (not great order but need break from matches)
# ^gonna have to use lines now, use lines, pull same word cleaning process from rap clean when runnign through class word
#
# gotta adddress the near match stuff
# make an excpetions dic - so far 17 words in 50 verses for del
#
# down the line
# keep modeling and coming up with stuff!

# %%
#estconn.close()
