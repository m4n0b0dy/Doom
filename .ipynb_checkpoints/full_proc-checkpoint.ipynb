# %%
import RAP_MASTER_LIB
#MY LIBRARIES -- towards the end of project/when you need a break write up documentaiton of libraries
#another library for plotting and testing
from rap_scrpr import *
from rap_db import *
from rap_clean import*
from rap_viz import *
#import nltk
#nltk.download()
#estconn = pg2.connect(database='rap_songs', user='keenan', host='localhost', password='keenan')

# %%
#i'd say find your favorite verses now that everything works
#for code below, since there is change to rap clean, need to re run cleaning.
#next time at home
#scrape, add to db
#only load clean objects for doom, del
#test that see if you like it then run rest overnight

# %%
#estconn = pg2.connect(database='rap_songs', user='keenan', host='localhost', password='keenan')
#next time with DB
#some_more = ['Donnie Trumpet &amp; The Social Experiment', 'Danny Brown', 'Denzel Curry', 'Black Star']
#might have trouble with donnie trumpet
#new_artists = scrape_multi_artists(estconn, some_more)
#create_music_tables(estconn, bypass = True)
#bulk_load(estconn, new_artists)
#need to remake chance
#still need to scrape these
#make_these = ['Mos Def', 'Talib Kweli', 'Danny Brown', 'Denzel Curry', 'Chance']
#works_pull = dict(zip(l2, construct_artists(estconn, art_list = l2)))
#art_save(works_pull)
#i think del was pulled with a space after del but double check it

# %%
#lst = ['Del', 'Eminem', 'Jay-Z', 'Chance', '50_Cent', 'Doom', 'Earl', 'Amine']
#NEED TO RE RUN WITH [] FILTERING
lst = ['Del', 'Chance', 'Doom', 'Earl', 'Mos Def', 'Talib Kweli', 'Danny Brown', 'Denzel Curry']
works = art_load(lst)
sub_works = {'Del':works['Del'], 'Chance':works['Chance'], 'Doom':works['Doom'], 'Earl':works['Earl']}

# %%
vs = unique_verses_bar(works.values())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="ad001c63-5490-4926-9d1c-272952d8030c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ad001c63-5490-4926-9d1c-272952d8030c", [{"type": "bar", "x": [57, 15, 115, 65, 26, 53, 42, 10, 19, 12], "orientation": "h", "text": ["Now I catch more wreck with fast ignition<br>My last decision, pulse amplification<br>Terror with napalm, I want y'all to stay calm<br>Alien annihilation, I stay armed to the grill piece and kill beef<br>20 percent matter, 30 percent is energy<br>Assimilating to become a living being<br>Evaporative radiation fades your station<br>I get high as aviation<br>Song: \"Positive Contact\" - Verse: #0 - Score:(0.86)", "The possibility of extraterrestrial contact was all fact<br>Humans were the first stage of attack<br>Song: \"What Is This Loneliness\" - Verse: #2 - Score:(0.867)", "Yo, avoiding the corporate sector running with the rebel operatives<br>Pulling a dark saber out on hostages<br>Deltron O from the under city wonders will they never cease<br>Fear of black planet, serious heat<br>Here in the street high doubts and strongholds<br>Action adventures go beyond the globe<br>The lost ones mobbing in repulsive trucks<br>Transporting troops and not for sport<br>My measurement systems are pleasant for listening<br>Imperial decree that legalizes conditions in certain instances<br>Battle techniques require split second timing<br>The usage designed with large spacecrafts in mind highly maneuverable<br>Turbo lasers will do more than subdue them fools<br>Provincial governor peripheral cameras cover<br>Every corner and crevice I catch a glimpse at<br>Song: \"Nobody Can\" - Verse: #0 - Score:(0.87)", "Hurrah, here come Del to dispel the blahs<br>Cause and effect, pause for respect collection<br>Diction friction, depicting violence<br>Volatile with my profile, like Molotov's<br>MC's must be on auto-pilot, waddle silent<br>like some platypuses, Del is down with data pushers<br>with top secret floppy disk and battle armor and mega<br>Plus all the rhymes that I'm bangin are double-decker, to check ya<br>Song: \"Oakland Blackouts\" - Verse: #1 - Score:(0.877)", "Natural resources nearly depleted to the point that human extinction clearly begins<br>By mankind's folly
"mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [5.3393501805054155, 5.470355731225297, 5.782978723404256, 5.720164609053498, 5.71356783919598, 5.97212543554007, 6.070921985815603, 5.334426229508197, 5.757062146892656], "y": [0.5573440643863179, 0.6893732970027248, 0.6831395348837209, 0.680672268907563, 0.6958041958041958, 0.7247474747474747, 0.7747252747252747, 0.6051587301587301, 0.69140625], "text": ["Pay the Price", "The Return", "Talent Supercedes", "The Agony", "Do You Remember?", "Nobody Can", "What Is This Loneliness", "Melding of the Minds", "Look Across the Sky"], "name": "Del: Event 2", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.976190476190476], "y": [0.7875], "text": ["All We Know"], "name": "Del: World War One: The Voice of Reason", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [5.052083333333333, 4.911538461538462, 4.694915254237288, 4.389705882352941], "y": [0.5603112840466926, 0.5726872246696035, 0.39464882943143814, 0.5938864628820961], "text": ["Catch a Bad One", "No Need for Alarm", "Wack M.C.'s", "Worldwide"], "name": "Del: No Need for Alarm", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.794642857142857, 4.985714285714286], "y": [0.469601677148847, 0.4886561954624782], "text": ["Love is worth", "Don't Forget the Bass"], "name": "Del: Future Development", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.8860103626943, 4.623655913978495, 5.486404833836858, 5.449468085106383, 4.5285714285714285, 5.426356589147287, 5.507177033492823, 4.993333333333333, 5.338842975206612], "y": [0.5346260387811634, 0.5740740740740741, 0.6700404858299596, 0.632996632996633, 0.6334841628959276, 0.6277372262773723, 0.6920529801324503, 0.6048387096774194, 0.6095717884130982], "text": ["Shit Talkers *", "Followers *", "Press Rewind", "Time is Too Expensive", "FWA (Fair Weather Associates) *", "Offspring", "Jaw Gymnastics", "Stay On Your Toes", "Catch All This"], "name": "Del: Both Sides of the Brain", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [], "y": [], "text": [], "name": "Del: Future Development (1996)", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [], "y": [], "text": [], "name": "Del: Phony Phranchise 12\"", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [5.137254901960785], "y": [0.8031496062992126], "text": ["Strange Universe"], "name": "Del: Strange Journey Volume Three", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.921487603305785], "y": [0.5307017543859649], "text": ["The Repo Man Sings for You"], "name": "Del: Steal This Album", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [], "y": [], "text": [], "name": "Del: Deltron 3030 ", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [], "y": [], "text": [], "name": "Del: Event II", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [], "y": [], "text": [], "name": "Del: Strength Magazine Presents Subtext (Compilation)", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.902702702702703], "y": [0.6146179401993356], "text": ["Hoe!"], "name": "Del: Defenders of the Underworld (Compilation)", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [5.29126213592233, 5.02020202020202], "y": [0.762962962962963, 0.7226277372262774], "text": ["On the Run Again" ...

# %%
artist_name, song_name = 'Doom', 'Bada Bing'
bada_bing = verse_graph(verse_search(works[artist_name], song_name), artist_name, song_name)
bada_bing.opto_matches(pop=2, exc_line=False, opto_type='exact')
bada_bing.colorize_vowels('near')
bada_bing.graph_colored_verse()
display(HTML(bada_bing.base_html))
# Out:
# Found: Bada Bing!
# Changed 50 sylbs!
# <html><style>h1{font-size:40pt;}h2{font-size:20pt;}
#         mark{margin-right:-7.4px;font-family:Arial;font-size:14pt;background-clip:content-box;}
#         mark:hover {cursor:help;position: relative}
#         mark span {display:none}
#         mark:hover span {display:block;z-index:1;white-space:nowrap;background:white;color:black;position:absolute;left:0px;margin:10px;top:10px;}mark.AW{background-color: rgba(18,18,127,.5);}mark.OW{background-color: rgba(234,240,115,.5);}mark.EY{background-color: rgba(0,0,0,.5);}mark.AH{background-color: rgba(90,92,123,.5);}mark.AE{background-color: rgba(198,203,117,.5);}mark.ER{background-color: rgba(126,129,121,.5);}mark.UW{background-color: rgba(253,2,242,.5);}mark.AA{background-color: rgba(54,55,125,.5);}mark.IH{background-color: rgba(216,221,244,.5);}mark.EH{background-color: rgba(162,166,119,.5);}mark.AO{background-color: rgba(108,110,250,.5);}mark.IY{background-color: rgba(36,36,254,.5);}mark.AY{background-color: rgba(72,73,252,.5);}mark.UH{background-color: rgba(180,184,246,.5);}mark.un{background-color: transparent;}</style><body><h1>Verse breakdown for Bada Bing by Doom</h1><h2>Vowel Color Legend<br></h2><mark class="AW">AW<span>(Count:16)</span></mark> <mark class="OW">OW<span>(Count:37)</span></mark> <mark class="EY">EY<span>(Count:48)</span></mark> <mark class="AH">AH<span>(Count:123)</span></mark> <mark class="AE">AE<span>(Count:17)</span></mark> <mark class="ER">ER<span>(Count:26)</span></mark> <mark class="UW">UW<span>(Count:21)</span></mark> <mark class="AA">AA<span>(Count:37)</span></mark> <mark class="IH">IH<span>(Count:98)</span></mark> <mark class="EH">EH<span>(Count:39)</span></mark> <mark class="AO">AO<span>(Count:20)</span></mark> <mark class="IY">IY<span>(Count:56)</span></mark> <mark class="AY">AY<span>(Count:33)</span></mark> <mark class="UH">UH<span>(Count:4)</span></mark> <mark class="un">un<span>(Count:1)</span></mark> <br><br><mark class="AA">Not<span>(Sylbl:"Not", Vowel:AA)</span></mark>     <mark class="AH">a<span>(Sylbl:"a", Vowel:AH)</span></mark>     <mark class="AA">lot<span>(Sylbl:"lot", Vowel:AA)</span></mark>     <mark class="AH">of<span>(Sylbl:"of", Vowel:AH)</span></mark>     <mark class="IH">bling<span>(Sylbl:"bling", Vowel:IH)</span></mark>     <br><mark class="IH">When<span>(Sylbl:"When", Vowel:IH)</span></mark>     <mark class="IY">he<span>(Sylbl:"he", Vowel:IY)</span></mark>     <mark class="UW">do<span>(Sylbl:"do", Vowel:UW)</span></mark>     <mark class="AH">the<span>(Sylbl:"the", Vowel:AH)</span></mark>     <mark class="IH">thing<span>(Sylbl:"thing", Vowel:IH)</span></mark>     <mark class="AA">ba<span>(Sylbl:"ba", Vowel:AA)</span></mark><mark class="AH">da<span>(Sylbl:"da", Vowel:AH)</span></mark>     <mark class="UW">boom<span>(Sylbl:"boom", Vowel:UW)</span></mark>     <mark class="AA">ba<span>(Sylbl:"ba", Vowel:AA)</span></mark><mark class="AH">da<span>(Sylbl:"da", Vowel:AH)</span></mark>     <mark class="IH">bing<span>(Sylbl:"bing", Vowel:IH)</span></mark>     <br><mark class="AH">From<span>(Sylbl:"From", Vowel:AH)</span></mark>     <mark class="AH">the<span>(Sylbl:"the", Vowel:AH)</span></mark>     <mark class="UW">womb<span>(Sylbl:"womb", Vowel:UW)</span></mark>     <mark class="AH">to<span>(Sylbl:"to", Vowel:AH)</span></mark>     <mark class="AH">the<span>(Sylbl:"the", Vowel:AH)</span></mark>     <mark class="UW">tomb<span>(Sylbl:"tomb", Vowel:UW)</span></mark>     <br><mark class="IH">Get<span>(Sylbl:"Get", Vowel:IH)</span></mark>     <mark class="AH">that<span>(Sylbl:"that", Vowel:AH)</span></mark>     <mark class="IY">ri<span>(Sylbl:"ri", Vowel:IY)</span></mark><mark class="OW">cot<span>(Sylbl:"cot", Vowel:OW)</span></mark><mark class="AH">ta<span>(Sylbl:"ta", Vowel:AH)</span></mark>     <mark class="AA">ba<span>(Sylbl:"ba", Vowel:AA)</span></mark><mark class="AH">da<span>(Sylbl:"da", Vowel:AH)</span></mark>     <mark class="IH">bing<span>(Sylbl:"bing", Vowel:IH)</span></mark>     <mark class="AA">ba<span>(Sylbl:"ba", Vowel:AA)</span></mark><mark class="AH">da<span>(Sylbl:"da", Vowel:AH)</span></mark>     <mark class="UW">boom<span>(Sylbl:"boom", Vowel:UW)</span></mark>     <br><mark class="UW">Doom<span>(Sylbl:"Doom", Vowel:UW)</span></mark>     <mark class="AO">yo ...

# %%
artist_name = 'Chance'
song_name = 'Favorite Song'
fav_song = verse_graph(verse_search(works[artist_name], song_name, verse_number=0), artist_name, song_name)

fav_song.colorize_vowels(match_type='exact')
fav_song.graph_colored_verse()
display(HTML(fav_song.base_html))
# Out:
# Found: Favorite Song!
# <html><style>h1{font-size:40pt;}h2{font-size:20pt;}
#         mark{margin-right:-7.4px;font-family:Arial;font-size:14pt;background-clip:content-box;}
#         mark:hover {cursor:help;position: relative}
#         mark span {display:none}
#         mark:hover span {display:block;z-index:1;white-space:nowrap;background:white;color:black;position:absolute;left:0px;margin:10px;top:10px;}mark.UH1{background-color: rgba(66,148,251,.5);}mark.OW2{background-color: rgba(199,190,241,.5);}mark.IH1{background-color: rgba(39,242,253,.5);}mark.AH0{background-color: rgba(173,28,243,.5);}mark.AA1{background-color: rgba(53,67,252,.5);}mark.AY1{background-color: rgba(146,122,245,.5);}mark.EY1{background-color: rgba(79,229,250,.5);}mark.AE1{background-color: rgba(239,177,238,.5);}mark.AH1{background-color: rgba(159,203,244,.5);}mark.IY1{background-color: rgba(226,96,239,.5);}mark.UW1{background-color: rgba(186,109,242,.5);}mark.EH1{background-color: rgba(106,135,248,.5);}mark.IH0{background-color: rgba(133,41,246,.5);}mark.IY0{background-color: rgba(93,54,249,.5);}mark.OW1{background-color: rgba(253,2,237,.5);}mark.AO1{background-color: rgba(119,216,247,.5);}mark.AE2{background-color: rgba(0,0,0,.5);}mark.ER0{background-color: rgba(213,15,240,.5);}mark.AA0{background-color: rgba(13,80,255,.5);}mark.unk{background-color: transparent;}</style><body><h1>Verse breakdown for Favorite Song by Chance</h1><h2>Vowel Color Legend<br></h2><mark class="UH1">UH1<span>(Count:1)</span></mark> <mark class="OW2">OW2<span>(Count:1)</span></mark> <mark class="IH1">IH1<span>(Count:14)</span></mark> <mark class="AH0">AH0<span>(Count:11)</span></mark> <mark class="AA1">AA1<span>(Count:3)</span></mark> <mark class="AY1">AY1<span>(Count:12)</span></mark> <mark class="EY1">EY1<span>(Count:1)</span></mark> <mark class="AE1">AE1<span>(Count:33)</span></mark> <mark class="AH1">AH1<span>(Count:8)</span></mark> <mark class="IY1">IY1<span>(Count:5)</span></mark> <mark class="UW1">UW1<span>(Count:9)</span></mark> <mark class="EH1">EH1<span>(Count:3)</span></mark> <mark class="IH0">IH0<span>(Count:4)</span></mark> <mark class="IY0">IY0<span>(Count:1)</span></mark> <mark class="OW1">OW1<span>(Count:4)</span></mark> <mark class="AO1">AO1<span>(Count:6)</span></mark> <mark class="AE2">AE2<span>(Count:1)</span></mark> <mark class="ER0">ER0<span>(Count:1)</span></mark> <mark class="AA0">AA0<span>(Count:1)</span></mark> <mark class="unk">unk<span>(Count:%%unk%%)</span></mark> <br><br><mark class="AH1">Young<span>(Sylbl:"Young", Vowel:AH1)</span></mark>     <mark class="AE1">Ras<span>(Sylbl:"Ras", Vowel:AE1)</span></mark><mark class="AH0">cal<span>(Sylbl:"cal", Vowel:AH0)</span></mark>     <mark class="AE1">Flatts<span>(Sylbl:"Flatts", Vowel:AE1)</span></mark>     <mark class="AH1">young<span>(Sylbl:"young", Vowel:AH1)</span></mark>     <mark class="AE1">ass<span>(Sylbl:"ass", Vowel:AE1)</span></mark>     <mark class="IH1">kid<span>(Sylbl:"kid", Vowel:IH1)</span></mark>     <mark class="AE1">ass<span>(Sylbl:"ass", Vowel:AE1)</span></mark>     <mark class="UH1">could<span>(Sylbl:"could", Vowel:UH1)</span></mark>     <mark class="AE1">rap<span>(Sylbl:"rap", Vowel:AE1)</span></mark>     <mark class="AY1">IGH<span>(Sylbl:"IGH", Vowel:AY1)</span></mark>     <br><mark class="AH1">Fuck<span>(Sylbl:"Fuck", Vowel:AH1)</span></mark>     <mark class="AO1">all<span>(Sylbl:"all", Vowel:AO1)</span></mark>     <mark class="AH0">the<span>(Sylbl:"the", Vowel:AH0)</span></mark>     <mark class="AE1">fac<span>(Sylbl:"fac", Vowel:AE1)</span></mark><mark class="AH0">ul<span>(Sylbl:"ul", Vowel:AH0)</span></mark><mark class="IY0">ty<span>(Sylbl:"ty", Vowel:IY0)</span></mark>     <mark class="AH0">to<span>(Sylbl:"to", Vowel:AH0)</span></mark><mark class="AE1">bac<span>(Sylbl:"bac", Vowel:AE1)</span></mark><mark class="OW2">co<span>(Sylbl:"co", Vowel:OW2)</span></mark>     <mark class="AE1">pack<span>(Sylbl:"pack", Vowel:AE1)</span></mark><mark class="IH0">ing<span>(Sylbl:"ing", Vowel:IH0)</span></mark>     <mark class="AE1">ac<span>(Sylbl:"ac", Vowel:AE1)</span></mark><mark class="AH0">ro<span>(Sylbl:"ro", Vowel:AH0)</span></mark><mark class="AE2">bat<span>(Sylbl:"bat", Vowel:AE2)</span></mark>     <mark class="AY1">IGH<span>(Sylbl:"IGH", Vowe ...

# %%
artist_name = 'Del'
song_name = 'Virus'
virus = verse_graph(verse_search(works[artist_name], song_name, verse_number=1), artist_name, song_name)

virus.colorize_vowels(match_type='near')
virus.graph_colored_verse()
display(HTML(virus.base_html))
# Out:
# Found: Virus!
# <html><style>h1{font-size:40pt;}h2{font-size:20pt;}
#         mark{margin-right:-7.4px;font-family:Arial;font-size:14pt;background-clip:content-box;}
#         mark:hover {cursor:help;position: relative}
#         mark span {display:none}
#         mark:hover span {display:block;z-index:1;white-space:nowrap;background:white;color:black;position:absolute;left:0px;margin:10px;top:10px;}mark.AW{background-color: rgba(72,73,252,.5);}mark.OW{background-color: rgba(216,221,244,.5);}mark.EY{background-color: rgba(253,2,242,.5);}mark.AH{background-color: rgba(36,36,254,.5);}mark.AE{background-color: rgba(0,0,0,.5);}mark.ER{background-color: rgba(234,240,115,.5);}mark.UW{background-color: rgba(126,129,121,.5);}mark.AA{background-color: rgba(90,92,123,.5);}mark.IH{background-color: rgba(18,18,127,.5);}mark.EH{background-color: rgba(180,184,246,.5);}mark.AO{background-color: rgba(108,110,250,.5);}mark.IY{background-color: rgba(144,147,248,.5);}mark.AY{background-color: rgba(198,203,117,.5);}mark.UH{background-color: rgba(54,55,125,.5);}mark.un{background-color: transparent;}</style><body><h1>Verse breakdown for Virus by Del</h1><h2>Vowel Color Legend<br></h2><mark class="AW">AW<span>(Count:6)</span></mark> <mark class="OW">OW<span>(Count:12)</span></mark> <mark class="EY">EY<span>(Count:15)</span></mark> <mark class="AH">AH<span>(Count:67)</span></mark> <mark class="AE">AE<span>(Count:10)</span></mark> <mark class="ER">ER<span>(Count:13)</span></mark> <mark class="UW">UW<span>(Count:15)</span></mark> <mark class="AA">AA<span>(Count:16)</span></mark> <mark class="IH">IH<span>(Count:39)</span></mark> <mark class="EH">EH<span>(Count:12)</span></mark> <mark class="AO">AO<span>(Count:13)</span></mark> <mark class="IY">IY<span>(Count:14)</span></mark> <mark class="AY">AY<span>(Count:36)</span></mark> <mark class="UH">UH<span>(Count:1)</span></mark> <mark class="un">un<span>(Count:%%un%%)</span></mark> <br><br><mark class="IY">Se<span>(Sylbl:"Se", Vowel:IY)</span></mark><mark class="IH">cret<span>(Sylbl:"cret", Vowel:IH)</span></mark><mark class="IY">ly<span>(Sylbl:"ly", Vowel:IY)</span></mark>     <mark class="AA">plot<span>(Sylbl:"plot", Vowel:AA)</span></mark><mark class="IH">ting<span>(Sylbl:"ting", Vowel:IH)</span></mark>     <mark class="AO">your<span>(Sylbl:"your", Vowel:AO)</span></mark>     <mark class="IH">dem<span>(Sylbl:"dem", Vowel:IH)</span></mark><mark class="AY">ise<span>(Sylbl:"ise", Vowel:AY)</span></mark>     <br><mark class="AY">I<span>(Sylbl:"I", Vowel:AY)</span></mark>     <mark class="AA">wan<span>(Sylbl:"wan", Vowel:AA)</span></mark><mark class="AH">na<span>(Sylbl:"na", Vowel:AH)</span></mark>     <mark class="IH">de<span>(Sylbl:"de", Vowel:IH)</span></mark><mark class="AY">vise<span>(Sylbl:"vise", Vowel:AY)</span></mark>     <mark class="AH">a<span>(Sylbl:"a", Vowel:AH)</span></mark>     <mark class="AY">vir<span>(Sylbl:"vir", Vowel:AY)</span></mark><mark class="AH">us<span>(Sylbl:"us", Vowel:AH)</span></mark>     <br><mark class="UW">To<span>(Sylbl:"To", Vowel:UW)</span></mark>     <mark class="IH">bring<span>(Sylbl:"bring", Vowel:IH)</span></mark>     <mark class="AY">dire<span>(Sylbl:"dire", Vowel:AY)</span></mark>     <mark class="EY">straits<span>(Sylbl:"straits", Vowel:EY)</span></mark>     <mark class="UW">to<span>(Sylbl:"to", Vowel:UW)</span></mark>     <mark class="AO">your<span>(Sylbl:"your", Vowel:AO)</span></mark>     <mark class="IH">en<span>(Sylbl:"en", Vowel:IH)</span></mark><mark class="AY">vi<span>(Sylbl:"vi", Vowel:AY)</span></mark><mark class="AH">ron<span>(Sylbl:"ron", Vowel:AH)</span></mark><mark class="AH">ment<span>(Sylbl:"ment", Vowel:AH)</span></mark>     <br><mark class="AH">Crush<span>(Sylbl:"Crush", Vowel:AH)</span></mark>     <mark class="AO">your<span>(Sylbl:"your", Vowel:AO)</span></mark>     <mark class="AO">cor<span>(Sylbl:"cor", Vowel:AO)</span></mark><mark class="ER">po<span>(Sylbl:"po", Vowel:ER)</span></mark><mark class="EY">ra<span>(Sylbl:"ra", Vowel:EY)</span></mark><mark class="AH">tions<span>(Sylbl:"tions", Vowel:AH)</span></mark>     <mark class="IH">with<span>(Sylbl:"with", Vowel:IH)</span></mark>     <mark class="AH">a<span>(Sylbl:"a", Vowel:AH)</span></mark>     <mark class="AY">mild<span>(Sylbl:"mild", Vowel:AY ...

# %%
v_type = 'near'
virus.opto_matches(pop=2, exc_line=True, opto_type=v_type)
virus.colorize_vowels(match_type=v_type)
virus.graph_colored_verse()
display(HTML(virus.base_html))
# Out:
# Changed 18 sylbs!
# <html><style>h1{font-size:40pt;}h2{font-size:20pt;}
#         mark{margin-right:-7.4px;font-family:Arial;font-size:14pt;background-clip:content-box;}
#         mark:hover {cursor:help;position: relative}
#         mark span {display:none}
#         mark:hover span {display:block;z-index:1;white-space:nowrap;background:white;color:black;position:absolute;left:0px;margin:10px;top:10px;}mark.AW{background-color: rgba(253,2,242,.5);}mark.OW{background-color: rgba(0,0,0,.5);}mark.EY{background-color: rgba(144,147,248,.5);}mark.AH{background-color: rgba(198,203,117,.5);}mark.AE{background-color: rgba(90,92,123,.5);}mark.ER{background-color: rgba(180,184,246,.5);}mark.UW{background-color: rgba(126,129,121,.5);}mark.AA{background-color: rgba(108,110,250,.5);}mark.IH{background-color: rgba(54,55,125,.5);}mark.EH{background-color: rgba(216,221,244,.5);}mark.AO{background-color: rgba(72,73,252,.5);}mark.IY{background-color: rgba(162,166,119,.5);}mark.AY{background-color: rgba(234,240,115,.5);}mark.UH{background-color: rgba(18,18,127,.5);}mark.un{background-color: transparent;}</style><body><h1>Verse breakdown for Virus by Del</h1><h2>Vowel Color Legend<br></h2><mark class="AW">AW<span>(Count:6)</span></mark> <mark class="OW">OW<span>(Count:12)</span></mark> <mark class="EY">EY<span>(Count:15)</span></mark> <mark class="AH">AH<span>(Count:77)</span></mark> <mark class="AE">AE<span>(Count:8)</span></mark> <mark class="ER">ER<span>(Count:13)</span></mark> <mark class="UW">UW<span>(Count:8)</span></mark> <mark class="AA">AA<span>(Count:13)</span></mark> <mark class="IH">IH<span>(Count:42)</span></mark> <mark class="EH">EH<span>(Count:10)</span></mark> <mark class="AO">AO<span>(Count:14)</span></mark> <mark class="IY">IY<span>(Count:14)</span></mark> <mark class="AY">AY<span>(Count:36)</span></mark> <mark class="UH">UH<span>(Count:1)</span></mark> <mark class="un">un<span>(Count:%%un%%)</span></mark> <br><br><mark class="IY">Se<span>(Sylbl:"Se", Vowel:IY)</span></mark><mark class="IH">cret<span>(Sylbl:"cret", Vowel:IH)</span></mark><mark class="IY">ly<span>(Sylbl:"ly", Vowel:IY)</span></mark>     <mark class="AA">plot<span>(Sylbl:"plot", Vowel:AA)</span></mark><mark class="IH">ting<span>(Sylbl:"ting", Vowel:IH)</span></mark>     <mark class="AO">your<span>(Sylbl:"your", Vowel:AO)</span></mark>     <mark class="IH">dem<span>(Sylbl:"dem", Vowel:IH)</span></mark><mark class="AY">ise<span>(Sylbl:"ise", Vowel:AY)</span></mark>     <br><mark class="AY">I<span>(Sylbl:"I", Vowel:AY)</span></mark>     <mark class="AA">wan<span>(Sylbl:"wan", Vowel:AA)</span></mark><mark class="AH">na<span>(Sylbl:"na", Vowel:AH)</span></mark>     <mark class="IH">de<span>(Sylbl:"de", Vowel:IH)</span></mark><mark class="AY">vise<span>(Sylbl:"vise", Vowel:AY)</span></mark>     <mark class="AH">a<span>(Sylbl:"a", Vowel:AH)</span></mark>     <mark class="AY">vir<span>(Sylbl:"vir", Vowel:AY)</span></mark><mark class="AH">us<span>(Sylbl:"us", Vowel:AH)</span></mark>     <br><mark class="AH">To<span>(Sylbl:"To", Vowel:AH)</span></mark>     <mark class="IH">bring<span>(Sylbl:"bring", Vowel:IH)</span></mark>     <mark class="AY">dire<span>(Sylbl:"dire", Vowel:AY)</span></mark>     <mark class="EY">straits<span>(Sylbl:"straits", Vowel:EY)</span></mark>     <mark class="AH">to<span>(Sylbl:"to", Vowel:AH)</span></mark>     <mark class="AO">your<span>(Sylbl:"your", Vowel:AO)</span></mark>     <mark class="IH">en<span>(Sylbl:"en", Vowel:IH)</span></mark><mark class="AY">vi<span>(Sylbl:"vi", Vowel:AY)</span></mark><mark class="AH">ron<span>(Sylbl:"ron", Vowel:AH)</span></mark><mark class="AH">ment<span>(Sylbl:"ment", Vowel:AH)</span></mark>     <br><mark class="AH">Crush<span>(Sylbl:"Crush", Vowel:AH)</span></mark>     <mark class="AO">your<span>(Sylbl:"your", Vowel:AO)</span></mark>     <mark class="AO">cor<span>(Sylbl:"cor", Vowel:AO)</span></mark><mark class="ER">po<span>(Sylbl:"po", Vowel:ER)</span></mark><mark class="EY">ra<span>(Sylbl:"ra", Vowel:EY)</span></mark><mark class="AH">tions<span>(Sylbl:"tions", Vowel:AH)</span></mark>     <mark class="IH">with<span>(Sylbl:"with", Vowel:IH)</span></mark>     <mark class="AH">a<span>(Sylbl:"a", Vowel:AH)</span></mark>     <mark class="AY">mild<span>(Sylbl:"mild", Vowel:AY ...

# %%
#lol really not that good
artist_name = 'Mos Def'
song_name = 'Mathematics'
v_type='near'
pull = verse_graph(verse_search(works[artist_name], song_name, verse_number=1), artist_name, song_name)

pull.colorize_vowels(match_type=v_type)
pull.graph_colored_verse()
display(HTML(pull.base_html))
pull.opto_matches(pop=1, exc_line=True, opto_type=v_type)
pull.colorize_vowels(match_type=v_type)
pull.graph_colored_verse()
display(HTML(pull.base_html))
# Out:
# Found: Mathematics!
# <html><style>h1{font-size:40pt;}h2{font-size:20pt;}
#         mark{margin-right:-7.4px;font-family:Arial;font-size:14pt;background-clip:content-box;}
#         mark:hover {cursor:help;position: relative}
#         mark span {display:none}
#         mark:hover span {display:block;z-index:1;white-space:nowrap;background:white;color:black;position:absolute;left:0px;margin:10px;top:10px;}mark.AW{background-color: rgba(236,36,238,.5);}mark.OW{background-color: rgba(168,172,170,.5);}mark.OY{background-color: rgba(185,138,187,.5);}mark.EY{background-color: rgba(84,86,85,.5);}mark.AH{background-color: rgba(202,104,204,.5);}mark.AE{background-color: rgba(134,240,136,.5);}mark.ER{background-color: rgba(50,154,51,.5);}mark.UW{background-color: rgba(67,120,68,.5);}mark.AA{background-color: rgba(118,18,119,.5);}mark.IH{background-color: rgba(16,222,17,.5);}mark.EH{background-color: rgba(219,70,221,.5);}mark.AO{background-color: rgba(101,52,102,.5);}mark.IY{background-color: rgba(0,0,0,.5);}mark.AY{background-color: rgba(151,206,153,.5);}mark.UH{background-color: rgba(33,188,34,.5);}mark.un{background-color: transparent;}</style><body><h1>Verse breakdown for Mathematics by Mos Def</h1><h2>Vowel Color Legend<br></h2><mark class="AW">AW<span>(Count:3)</span></mark> <mark class="OW">OW<span>(Count:10)</span></mark> <mark class="OY">OY<span>(Count:2)</span></mark> <mark class="EY">EY<span>(Count:16)</span></mark> <mark class="AH">AH<span>(Count:88)</span></mark> <mark class="AE">AE<span>(Count:22)</span></mark> <mark class="ER">ER<span>(Count:18)</span></mark> <mark class="UW">UW<span>(Count:24)</span></mark> <mark class="AA">AA<span>(Count:12)</span></mark> <mark class="IH">IH<span>(Count:72)</span></mark> <mark class="EH">EH<span>(Count:21)</span></mark> <mark class="AO">AO<span>(Count:17)</span></mark> <mark class="IY">IY<span>(Count:34)</span></mark> <mark class="AY">AY<span>(Count:18)</span></mark> <mark class="UH">UH<span>(Count:1)</span></mark> <mark class="un">un<span>(Count:8)</span></mark> <br><br><mark class="OW">Yo<span>(Sylbl:"Yo", Vowel:OW)</span></mark>     <mark class="IH">its<span>(Sylbl:"its", Vowel:IH)</span></mark>     <mark class="AH">one<span>(Sylbl:"one", Vowel:AH)</span></mark>     <mark class="UW">un<span>(Sylbl:"un", Vowel:UW)</span></mark><mark class="AH">iv<span>(Sylbl:"iv", Vowel:AH)</span></mark><mark class="ER">ers<span>(Sylbl:"ers", Vowel:ER)</span></mark><mark class="AH">al<span>(Sylbl:"al", Vowel:AH)</span></mark>     <mark class="AO">law<span>(Sylbl:"law", Vowel:AO)</span></mark>     <mark class="AH">but<span>(Sylbl:"but", Vowel:AH)</span></mark>     <mark class="UW">two<span>(Sylbl:"two", Vowel:UW)</span></mark>     <mark class="AY">sides<span>(Sylbl:"sides", Vowel:AY)</span></mark>     <mark class="UW">to<span>(Sylbl:"to", Vowel:UW)</span></mark>     <mark class="EH">ev<span>(Sylbl:"ev", Vowel:EH)</span></mark><mark class="IY">ery<span>(Sylbl:"ery", Vowel:IY)</span></mark>     <mark class="AO">sto<span>(Sylbl:"sto", Vowel:AO)</span></mark><mark class="IY">ry<span>(Sylbl:"ry", Vowel:IY)</span></mark>     <br><mark class="IY">Three<span>(Sylbl:"Three", Vowel:IY)</span></mark>     <mark class="AY">strikes<span>(Sylbl:"strikes", Vowel:AY)</span></mark>     <mark class="AH">and<span>(Sylbl:"and", Vowel:AH)</span></mark>     <mark class="UW">you<span>(Sylbl:"you", Vowel:UW)</span></mark>     <mark class="IY">be<span>(Sylbl:"be", Vowel:IY)</span></mark>     <mark class="IH">in<span>(Sylbl:"in", Vowel:IH)</span></mark>     <mark class="AO">for<span>(Sylbl:"for", Vowel:AO)</span></mark>     <mark class="AY">life<span>(Sylbl:"life", Vowel:AY)</span></mark>     <mark class="AE">man<span>(Sylbl:"man", Vowel:AE)</span></mark><mark class="AH">di<span>(Sylbl:"di", Vowel:AH)</span></mark><mark class="AO">to<span>(Sylbl:"to", Vowel:AO)</span></mark><mark class="IY">ry<span>(Sylbl:"ry", Vowel:IY)</span></mark>     <br><mark class="AO">Four<span>(Sylbl:"Four", Vowel:AO)</span></mark>     <mark class="AE">MCs<span>(Sylbl:"MCs", Vowel:AE)</span></mark>     <mark class="ER">mur<span>(Sylbl:"mur", Vowel:ER)</span></mark><mark class="ER">dered<span>(Sylbl:"dered", Vowel:ER)</span></mark>     <mark class="IH">in<span>(Sylbl:"in", Vowel:IH)</span></mark>     <mark class ...
# Changed 22 sylbs!
# <html><style>h1{font-size:40pt;}h2{font-size:20pt;}
#         mark{margin-right:-7.4px;font-family:Arial;font-size:14pt;background-clip:content-box;}
#         mark:hover {cursor:help;position: relative}
#         mark span {display:none}
#         mark:hover span {display:block;z-index:1;white-space:nowrap;background:white;color:black;position:absolute;left:0px;margin:10px;top:10px;}mark.AW{background-color: rgba(101,52,102,.5);}mark.OW{background-color: rgba(134,240,136,.5);}mark.OY{background-color: rgba(16,222,17,.5);}mark.EY{background-color: rgba(202,104,204,.5);}mark.AH{background-color: rgba(236,36,238,.5);}mark.AE{background-color: rgba(50,154,51,.5);}mark.ER{background-color: rgba(33,188,34,.5);}mark.UW{background-color: rgba(67,120,68,.5);}mark.AA{background-color: rgba(118,18,119,.5);}mark.IH{background-color: rgba(0,0,0,.5);}mark.EH{background-color: rgba(168,172,170,.5);}mark.AO{background-color: rgba(151,206,153,.5);}mark.IY{background-color: rgba(84,86,85,.5);}mark.AY{background-color: rgba(219,70,221,.5);}mark.UH{background-color: rgba(185,138,187,.5);}mark.un{background-color: transparent;}</style><body><h1>Verse breakdown for Mathematics by Mos Def</h1><h2>Vowel Color Legend<br></h2><mark class="AW">AW<span>(Count:3)</span></mark> <mark class="OW">OW<span>(Count:10)</span></mark> <mark class="OY">OY<span>(Count:2)</span></mark> <mark class="EY">EY<span>(Count:16)</span></mark> <mark class="AH">AH<span>(Count:90)</span></mark> <mark class="AE">AE<span>(Count:18)</span></mark> <mark class="ER">ER<span>(Count:18)</span></mark> <mark class="UW">UW<span>(Count:14)</span></mark> <mark class="AA">AA<span>(Count:9)</span></mark> <mark class="IH">IH<span>(Count:86)</span></mark> <mark class="EH">EH<span>(Count:17)</span></mark> <mark class="AO">AO<span>(Count:20)</span></mark> <mark class="IY">IY<span>(Count:36)</span></mark> <mark class="AY">AY<span>(Count:18)</span></mark> <mark class="UH">UH<span>(Count:1)</span></mark> <mark class="un">un<span>(Count:8)</span></mark> <br><br><mark class="OW">Yo<span>(Sylbl:"Yo", Vowel:OW)</span></mark>     <mark class="IH">its<span>(Sylbl:"its", Vowel:IH)</span></mark>     <mark class="AH">one<span>(Sylbl:"one", Vowel:AH)</span></mark>     <mark class="UW">un<span>(Sylbl:"un", Vowel:UW)</span></mark><mark class="AH">iv<span>(Sylbl:"iv", Vowel:AH)</span></mark><mark class="ER">ers<span>(Sylbl:"ers", Vowel:ER)</span></mark><mark class="AH">al<span>(Sylbl:"al", Vowel:AH)</span></mark>     <mark class="AO">law<span>(Sylbl:"law", Vowel:AO)</span></mark>     <mark class="AH">but<span>(Sylbl:"but", Vowel:AH)</span></mark>     <mark class="UW">two<span>(Sylbl:"two", Vowel:UW)</span></mark>     <mark class="AY">sides<span>(Sylbl:"sides", Vowel:AY)</span></mark>     <mark class="IH">to<span>(Sylbl:"to", Vowel:IH)</span></mark>     <mark class="EH">ev<span>(Sylbl:"ev", Vowel:EH)</span></mark><mark class="IY">ery<span>(Sylbl:"ery", Vowel:IY)</span></mark>     <mark class="AO">sto<span>(Sylbl:"sto", Vowel:AO)</span></mark><mark class="IY">ry<span>(Sylbl:"ry", Vowel:IY)</span></mark>     <br><mark class="IY">Three<span>(Sylbl:"Three", Vowel:IY)</span></mark>     <mark class="AY">strikes<span>(Sylbl:"strikes", Vowel:AY)</span></mark>     <mark class="AH">and<span>(Sylbl:"and", Vowel:AH)</span></mark>     <mark class="UW">you<span>(Sylbl:"you", Vowel:UW)</span></mark>     <mark class="IY">be<span>(Sylbl:"be", Vowel:IY)</span></mark>     <mark class="IH">in<span>(Sylbl:"in", Vowel:IH)</span></mark>     <mark class="AO">for<span>(Sylbl:"for", Vowel:AO)</span></mark>     <mark class="AY">life<span>(Sylbl:"life", Vowel:AY)</span></mark>     <mark class="AH">man<span>(Sylbl:"man", Vowel:AH)</span></mark><mark class="IH">di<span>(Sylbl:"di", Vowel:IH)</span></mark><mark class="AO">to<span>(Sylbl:"to", Vowel:AO)</span></mark><mark class="IY">ry<span>(Sylbl:"ry", Vowel:IY)</span></mark>     <br><mark class="AO">Four<span>(Sylbl:"Four", Vowel:AO)</span></mark>     <mark class="IH">MCs<span>(Sylbl:"MCs", Vowel:IH)</span></mark>     <mark class="ER">mur<span>(Sylbl:"mur", Vowel:ER)</span></mark><mark class="ER">dered<span>(Sylbl:"dered", Vowel:ER)</span></mark>     <mark class="IH">in<span>(Sylbl:"in", Vowel:IH)</span></mark>     <mark class= ...

# %%
#lol really not that good
artist_name = 'Earl'
song_name = 'Hoarse'
v_type='near'
pull = verse_graph(verse_search(works[artist_name], song_name, verse_number=0), artist_name, song_name)

pull.colorize_vowels(match_type=v_type)
pull.graph_colored_verse()
display(HTML(pull.base_html))
pull.opto_matches(pop=False, exc_line=False, opto_type=v_type)
pull.colorize_vowels(match_type=v_type)
pull.graph_colored_verse()
display(HTML(pull.base_html))
# Out:
# Found: Hoarse!
# <html><style>h1{font-size:40pt;}h2{font-size:20pt;}
#         mark{margin-right:-7.4px;font-family:Arial;font-size:14pt;background-clip:content-box;}
#         mark:hover {cursor:help;position: relative}
#         mark span {display:none}
#         mark:hover span {display:block;z-index:1;white-space:nowrap;background:white;color:black;position:absolute;left:0px;margin:10px;top:10px;}mark.AW{background-color: rgba(162,166,119,.5);}mark.OW{background-color: rgba(253,2,242,.5);}mark.EY{background-color: rgba(144,147,248,.5);}mark.AH{background-color: rgba(126,129,121,.5);}mark.AE{background-color: rgba(72,73,252,.5);}mark.ER{background-color: rgba(180,184,246,.5);}mark.UW{background-color: rgba(234,240,115,.5);}mark.AA{background-color: rgba(18,18,127,.5);}mark.IH{background-color: rgba(198,203,117,.5);}mark.EH{background-color: rgba(90,92,123,.5);}mark.AO{background-color: rgba(54,55,125,.5);}mark.IY{background-color: rgba(0,0,0,.5);}mark.AY{background-color: rgba(108,110,250,.5);}mark.UH{background-color: rgba(36,36,254,.5);}mark.un{background-color: transparent;}</style><body><h1>Verse breakdown for Hoarse by Earl</h1><h2>Vowel Color Legend<br></h2><mark class="AW">AW<span>(Count:1)</span></mark> <mark class="OW">OW<span>(Count:8)</span></mark> <mark class="EY">EY<span>(Count:18)</span></mark> <mark class="AH">AH<span>(Count:42)</span></mark> <mark class="AE">AE<span>(Count:5)</span></mark> <mark class="ER">ER<span>(Count:6)</span></mark> <mark class="UW">UW<span>(Count:1)</span></mark> <mark class="AA">AA<span>(Count:7)</span></mark> <mark class="IH">IH<span>(Count:48)</span></mark> <mark class="EH">EH<span>(Count:3)</span></mark> <mark class="AO">AO<span>(Count:20)</span></mark> <mark class="IY">IY<span>(Count:11)</span></mark> <mark class="AY">AY<span>(Count:4)</span></mark> <mark class="UH">UH<span>(Count:4)</span></mark> <mark class="un">un<span>(Count:2)</span></mark> <br><br><mark class="AO">Gor<span>(Sylbl:"Gor", Vowel:AO)</span></mark><mark class="AH">geous<span>(Sylbl:"geous", Vowel:AH)</span></mark>     <mark class="OW">chrome<span>(Sylbl:"chrome", Vowel:OW)</span></mark>     <mark class="EY">plat<span>(Sylbl:"plat", Vowel:EY)</span></mark><mark class="AH">ed<span>(Sylbl:"ed", Vowel:AH)</span></mark>     <mark class="AO">horse<span>(Sylbl:"horse", Vowel:AO)</span></mark>     <mark class="IH">whip<span>(Sylbl:"whip", Vowel:IH)</span></mark>     <br><mark class="OW">Home<span>(Sylbl:"Home", Vowel:OW)</span></mark>     <mark class="EY">mak<span>(Sylbl:"mak", Vowel:EY)</span></mark><mark class="IH">ing<span>(Sylbl:"ing", Vowel:IH)</span></mark>     <mark class="EY">paint<span>(Sylbl:"paint", Vowel:EY)</span></mark><mark class="IH">ings<span>(Sylbl:"ings", Vowel:IH)</span></mark>     <mark class="AO">for<span>(Sylbl:"for", Vowel:AO)</span></mark>     <mark class="UH">poor<span>(Sylbl:"poor", Vowel:UH)</span></mark>     <mark class="AA">qual<span>(Sylbl:"qual", Vowel:AA)</span></mark><mark class="AH">i<span>(Sylbl:"i", Vowel:AH)</span></mark><mark class="IY">ty<span>(Sylbl:"ty", Vowel:IY)</span></mark>     <mark class="AO">porn<span>(Sylbl:"porn", Vowel:AO)</span></mark>     <mark class="IH">flicks<span>(Sylbl:"flicks", Vowel:IH)</span></mark>     <br><mark class="AO">Court<span>(Sylbl:"Court", Vowel:AO)</span></mark>     <mark class="AH">ad<span>(Sylbl:"ad", Vowel:AH)</span></mark><mark class="ER">journed<span>(Sylbl:"journed", Vowel:ER)</span></mark>     <mark class="AH">and<span>(Sylbl:"and", Vowel:AH)</span></mark>     <mark class="AH">the<span>(Sylbl:"the", Vowel:AH)</span></mark>     <mark class="ER">ver<span>(Sylbl:"ver", Vowel:ER)</span></mark><mark class="IH">dicts<span>(Sylbl:"dicts", Vowel:IH)</span></mark>     <mark class="IH">still<span>(Sylbl:"still", Vowel:IH)</span></mark>     <mark class="AO">sauc<span>(Sylbl:"sauc", Vowel:AO)</span></mark><mark class="IY">y<span>(Sylbl:"y", Vowel:IY)</span></mark>     <br><mark class="AE">Sack<span>(Sylbl:"Sack", Vowel:AE)</span></mark>     <mark class="IH">swing<span>(Sylbl:"swing", Vowel:IH)</span></mark><mark class="IH">ing<span>(Sylbl:"ing", Vowel:IH)</span></mark>     <mark class="AY">like<span>(Sylbl:"like", Vowel:AY)</span></mark>     <mark class="AH">Dub<span>(Sylbl:"Dub", Vowel:AH)</span></mark>   ...
# Changed 6 sylbs!
# <html><style>h1{font-size:40pt;}h2{font-size:20pt;}
#         mark{margin-right:-7.4px;font-family:Arial;font-size:14pt;background-clip:content-box;}
#         mark:hover {cursor:help;position: relative}
#         mark span {display:none}
#         mark:hover span {display:block;z-index:1;white-space:nowrap;background:white;color:black;position:absolute;left:0px;margin:10px;top:10px;}mark.AW{background-color: rgba(108,110,250,.5);}mark.OW{background-color: rgba(234,240,115,.5);}mark.EY{background-color: rgba(162,166,119,.5);}mark.AH{background-color: rgba(126,129,121,.5);}mark.AE{background-color: rgba(90,92,123,.5);}mark.ER{background-color: rgba(72,73,252,.5);}mark.UW{background-color: rgba(253,2,242,.5);}mark.AA{background-color: rgba(198,203,117,.5);}mark.IH{background-color: rgba(0,0,0,.5);}mark.EH{background-color: rgba(36,36,254,.5);}mark.AO{background-color: rgba(216,221,244,.5);}mark.IY{background-color: rgba(144,147,248,.5);}mark.AY{background-color: rgba(54,55,125,.5);}mark.UH{background-color: rgba(180,184,246,.5);}mark.un{background-color: transparent;}</style><body><h1>Verse breakdown for Hoarse by Earl</h1><h2>Vowel Color Legend<br></h2><mark class="AW">AW<span>(Count:1)</span></mark> <mark class="OW">OW<span>(Count:8)</span></mark> <mark class="EY">EY<span>(Count:18)</span></mark> <mark class="AH">AH<span>(Count:41)</span></mark> <mark class="AE">AE<span>(Count:4)</span></mark> <mark class="ER">ER<span>(Count:6)</span></mark> <mark class="UW">UW<span>(Count:1)</span></mark> <mark class="AA">AA<span>(Count:5)</span></mark> <mark class="IH">IH<span>(Count:51)</span></mark> <mark class="EH">EH<span>(Count:3)</span></mark> <mark class="AO">AO<span>(Count:22)</span></mark> <mark class="IY">IY<span>(Count:11)</span></mark> <mark class="AY">AY<span>(Count:4)</span></mark> <mark class="UH">UH<span>(Count:3)</span></mark> <mark class="un">un<span>(Count:2)</span></mark> <br><br><mark class="AO">Gor<span>(Sylbl:"Gor", Vowel:AO)</span></mark><mark class="AH">geous<span>(Sylbl:"geous", Vowel:AH)</span></mark>     <mark class="OW">chrome<span>(Sylbl:"chrome", Vowel:OW)</span></mark>     <mark class="EY">plat<span>(Sylbl:"plat", Vowel:EY)</span></mark><mark class="IH">ed<span>(Sylbl:"ed", Vowel:IH)</span></mark>     <mark class="AO">horse<span>(Sylbl:"horse", Vowel:AO)</span></mark>     <mark class="IH">whip<span>(Sylbl:"whip", Vowel:IH)</span></mark>     <br><mark class="OW">Home<span>(Sylbl:"Home", Vowel:OW)</span></mark>     <mark class="EY">mak<span>(Sylbl:"mak", Vowel:EY)</span></mark><mark class="IH">ing<span>(Sylbl:"ing", Vowel:IH)</span></mark>     <mark class="EY">paint<span>(Sylbl:"paint", Vowel:EY)</span></mark><mark class="IH">ings<span>(Sylbl:"ings", Vowel:IH)</span></mark>     <mark class="AO">for<span>(Sylbl:"for", Vowel:AO)</span></mark>     <mark class="UH">poor<span>(Sylbl:"poor", Vowel:UH)</span></mark>     <mark class="AA">qual<span>(Sylbl:"qual", Vowel:AA)</span></mark><mark class="AH">i<span>(Sylbl:"i", Vowel:AH)</span></mark><mark class="IY">ty<span>(Sylbl:"ty", Vowel:IY)</span></mark>     <mark class="AO">porn<span>(Sylbl:"porn", Vowel:AO)</span></mark>     <mark class="IH">flicks<span>(Sylbl:"flicks", Vowel:IH)</span></mark>     <br><mark class="AO">Court<span>(Sylbl:"Court", Vowel:AO)</span></mark>     <mark class="AH">ad<span>(Sylbl:"ad", Vowel:AH)</span></mark><mark class="ER">journed<span>(Sylbl:"journed", Vowel:ER)</span></mark>     <mark class="AH">and<span>(Sylbl:"and", Vowel:AH)</span></mark>     <mark class="AH">the<span>(Sylbl:"the", Vowel:AH)</span></mark>     <mark class="ER">ver<span>(Sylbl:"ver", Vowel:ER)</span></mark><mark class="IH">dicts<span>(Sylbl:"dicts", Vowel:IH)</span></mark>     <mark class="IH">still<span>(Sylbl:"still", Vowel:IH)</span></mark>     <mark class="AO">sauc<span>(Sylbl:"sauc", Vowel:AO)</span></mark><mark class="IY">y<span>(Sylbl:"y", Vowel:IY)</span></mark>     <br><mark class="AE">Sack<span>(Sylbl:"Sack", Vowel:AE)</span></mark>     <mark class="IH">swing<span>(Sylbl:"swing", Vowel:IH)</span></mark><mark class="IH">ing<span>(Sylbl:"ing", Vowel:IH)</span></mark>     <mark class="AY">like<span>(Sylbl:"like", Vowel:AY)</span></mark>     <mark class="AH">Dub<span>(Sylbl:"Dub", Vowel:AH)</span></mark> ...

# %% [markdown]
# estconn = pg2.connect(database='rap_songs', user='keenan', host='localhost', password='keenan')
# bob_dylan = dict(zip(['Bob Dylan'], construct_artists(estconn, art_list = ['Bob Dylan'])))
#
# artist_name = 'Bob Dylan'
# song_name = 'Subterranean Homesick Blues'
# bd = verse_graph(verse_search(bob_dylan[artist_name], song_name), artist_name, song_name)
# bd.colorize_vowels('near')
# bd.graph_colored_verse()
# display(HTML(bd.base_html))
#
# bd.opto_matches(pop=3, exc_line=True, opto_type='near')
# bd.colorize_vowels('near')
# bd.graph_colored_verse()
# display(HTML(bd.base_html))

# %% [markdown]
# what you did
# ran sylbl and word creation at rap clean level
# IT FUUUUUUCKING WORKKKKKKS
#
# what's next
# clean rap clean viz, rename and just tighten up
# next viz!
#
# errors
# need db for this one
# try loading in [] as it's own segment and not adding it list of verse segments (it;s ok to have in segment, can always filter later or include cause it is a part of the song)
# captiring for [] right now is anything without versse, brideg, chorus, intro, outro and it shouldn't caputre match.group()[1:-1] in COMPLETE_RAPPERS
#
# down the line
# keep modeling and coming up with stuff!

# %%
#estconn.close()
