# %%
import RAP_MASTER_LIB
#MY LIBRARIES -- towards the end of project/when you need a break write up documentaiton of libraries
#another library for plotting and testing
from rap_scrpr import *
from rap_db import *
from rap_clean import*
from rap_viz import *

from nltk.corpus import cmudict
syl_dict = cmudict.dict()
#from autocorrect import spell
wrds = set(syl_dict.keys())
from difflib import get_close_matches

estconn = pg2.connect(database='rap_songs', user='keenan', host='localhost', password='keenan')
#import nltk
#nltk.download()
#create_music_tables(estconn)

# %%
lst = ['Del', 'Eminem', 'Jay-Z', 'Chance', '50_Cent', 'Doom']

# %% [markdown]
# #need to remake art objs
# #new_artists = scrape_multi_artists(estconn, ['10sion'])
# #create_music_tables(estconn, bypass = True)
# #bulk_load(estconn, new_artists)
# #lst = ['Del', 'Eminem', 'Jay-Z', 'Chance', '50_Cent', 'Doom']
# #l2 = ['Del']
# #works_pull = dict(zip(lst, construct_artists(estconn, art_list = lst)))
# #art_save(works_pull)

# %%
#works_pull = dict(zip(lst, construct_artists(estconn, art_list = lst)))
#art_save(works_pull)

# %%
works = art_load(lst)

# %%
sub_works = {'Del':works['Del'], 'Chance':works['Chance'], 'Doom':works['Doom']}

# %%
vs = unique_verses_bar(sub_works.values())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="bd65dd37-2efa-4fd7-b321-6059293e1194" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bd65dd37-2efa-4fd7-b321-6059293e1194", [{"type": "bar", "x": [111, 95, 54, 18, 115, 63, 53, 16, 18, 12], "orientation": "h", "text": ["The humanoid race feels that they should rule the whole space-time continuum<br>Decimating villages<br>Deltron, the hero of alliance is sent forth<br>To insure chief aids don't catch a heat ray<br>I just scoped this fiber rope<br>It looks like a good conductor of electricity<br>Use it for a stun net for anyone stepping in the vicinity<br>Living within the walls of our buildings<br>Impervious surface, industrial strength<br>Heavy-duty shield generators for hater attempts<br>Metallic content within the star ship<br>Computer system shoots us through parsecs<br>Light years, astronomical units<br>NASA couldn't fathom the havoc they producing<br>Measured in fractions involving objects from a single star system but yet so complex<br>(0.829)", "How did it happen An independent corporation<br>With no control could maintain it<br>With rebellious force, developed a course of action<br>We advertise, inviting all to court, the massive<br>A queen's faithful hand, maidens born to wealthy parents<br>A life of luxury, but full of scorn, yeah, they be jealous<br>We were omnivores, gathered food with our tongues<br>Peaceful, unprepared against the guns<br>Ever since we was young they slayed our real master<br>Now I'm told, blast the rifles to peel back domes<br>Heavy weapon power sources for confrontation<br>Against hot situations, safe world's invaded<br>(0.832)", "A hundred and fourteen and more fiend<br>Proportion, black mortality casualty<br>Gradually losin grips with reality<br>When a child's view in violence so casually<br>Callously, carousel of confusion<br>Only comes to a halt with thoughtful conclusions<br>I'ma weigh the pros and cons of what's goin on<br>Decide whether to go beyond and go along<br>(0.833)", " <br>\"You trippin' man.\"<br>\"Man I be grindin' and chillin'<br> Nigga, I was rolling dice the other day nigga.\" <br>(0.833)", "Yo, avoiding the corporate sector running with the rebel operatives<br>Pulling a dark saber out on hostages<br>Deltron O from the under city wonders will they never cease<br>Fear of black planet, serious heat<br>Here in the street high doubts and strongholds<br>Action adventures go beyond the globe<br>The lost ones mobbing in repulsive trucks<br>Transporting troops and not for sport<br>My measurement systems are pleasant for listening<br>Imperial decree that legalizes conditions in certain instances<br>Battle techniques require split second timing<br>The usage designed with large spacecrafts in mind highly maneuverable<br>Turbo lasers will do more than subdue them fools<br>Provincial governor perip
493, 0.6366666666666667, 0.7448275862068966, 0.49429657794676807, 0.5979166666666667, 0.677570093457944, 0.391304347826087, 0.74, 0.4988344988344988, 0.6238938053097345, 0.5312934631432545, 0.688622754491018], "text": ["Virus", "Positive Contact", "Things You Can Do", "Hoe!", "On the Run Again", "War of the Masses", "Pay the Price", "The Return", "Talent Supercedes", "The Agony", "What Is This Loneliness", "Do You Remember?", "Nobody Can", "Melding of the Minds", "Look Across the Sky", "All We Know", "Catch a Bad One", "No Need for Alarm", "Wack M.C.'s", "Worldwide", "Love is worth", "Don't Forget the Bass", "Jaw Gymnastics", "Shit Talkers *", "Followers *", "Press Rewind", "Time is Too Expensive", "FWA (Fair Weather Associates) *", "Offspring", "Stay On Your Toes", "Catch All This", "Strange Universe", "The Repo Man Sings for You", "Three Emcees", "What's Wrong with This Picture", "Oakland Blackouts", "Off the Record", "Get It", "Food Fight", "Nothing Fake/The Ultimate", "The World's Gone Mad", "Magnetizing", "The Projects (PJays)", "Clint Eastwood", "Preservation", "Fragments", "Undisputed Champs", "'94 Via Satellite", "Ride Slow"], "name": "Del", "mode": "markers", "hoverinfo": "text"}, {"type": "scatter", "x": [4.098039215686274, 5.137795275590551, 4.432624113475177, 5.292307692307692, 5.115384615384615, 4.762931034482759, 5.040462427745664, 4.763888888888889, 4.403846153846154, 4.496732026143791, 4.421768707482993, 4.648, 4.981651376146789, 4.903381642512077, 4.6923076923076925, 5.268595041322314, 4.223684210526316, 4.479166666666667, 5.0353535353535355, 5.092356687898089, 4.7388059701492535, 4.5271739130434785, 4.725, 4.512195121951219, 4.549763033175355, 4.782828282828283, 4.494736842105263, 4.275862068965517, 4.4213197969543145, 3.9767441860465116, 4.173913043478261, 4.418803418803419, 5.12, 5.053511705685619, 4.563157894736842, 4.516528925619835, 4.4148148148148145, 3.933333333333333, 4.352380952380952, 4.74, 4.703488372093023, 4.987261146496815, 4.744186046511628, 5. ...

# %%
a = 'Rap Ambush'
for c in works['Doom'].songs:
    if c.name == a:
        a = c
print(a.raw_text)
# Out:
# [Intro]
# So we're gonna stand on perimeter
# We did have some shots fired right down the street on us
# while this was goin on, so we gotta set up a tight perimeter
# We got the streets blocked off
# to make sure we don't have any drivebys on us
# Other than that, the operation went, fairly well...
#
# [Doom]
# Who told you that Rolled through, BRRRAT
# Old to the new knows who hold the hat
# Custom tailored fitted, head stayed same size
# Big since first born, well spree to game wise
# Same guys, same disguise, sick aim eye stare
# A thick dame thighs, click claim prize
# And the lucky contestant was sent
# a whole year's supply of buckets of yucky excrement
# Digital format, provide the ROM
# Riot calm, flow was like a roadside bomb
# Flipped the Humvee, impact was limb-numbing
# Cameraman wig back, gunner screaming INCOMING
# RPG, rhyme propelled grenade
# Time to yell, scramble for cover in the shade
# Bright as the midday sun, then it fade
# Darkness come quick, some run and get sprayed
# Rot dead, hot lead, it's rainin
# Left 'em with they brains kicked in with they trainin
# Dragged the remains into the open by the bootstraps
# Dogtag attached to explosive human booby traps
# Where's air support, ears ringin, mortars whistlin
# Bloodshot vision after thought abort mission
# Too little too late, as the last man gushed
# Took no prisoners mushed, rap ambush
#
# {MURDALIZING SUCKER EMCEES~!}

# %%
for d in a.uniq_art_verses:
    print(d.content, d.word_syls, len(d.unique_words), len(d.word_syls))
# Out:
# Who told you that Rolled through, BRRRAT
# Old to the new knows who hold the hat
# Custom tailored fitted, head stayed same size
# Big since first born, well spree to game wise
# Same guys, same disguise, sick aim eye stare
# A thick dame thighs, click claim prize
# And the lucky contestant was sent
# a whole year's supply of buckets of yucky excrement
# Digital format, provide the ROM
# Riot calm, flow was like a roadside bomb
# Flipped the Humvee, impact was limb-numbing
# Cameraman wig back, gunner screaming INCOMING
# RPG, rhyme propelled grenade
# Time to yell, scramble for cover in the shade
# Bright as the midday sun, then it fade
# Darkness come quick, some run and get sprayed
# Rot dead, hot lead, it's rainin
# Left 'em with they brains kicked in with they trainin
# Dragged the remains into the open by the bootstraps
# Dogtag attached to explosive human booby traps
# Where's air support, ears ringin, mortars whistlin
# Bloodshot vision after thought abort mission
# Too little too late, as the last man gushed
# Took no prisoners mushed, rap ambush
#
# {MURDALIZING SUCKER EMCEES~!} {'flipped': [['EH1', 'F']], 'new': [['EH1', 'N']], 'aim': [['AH0'], ['EY1']], 'whole': [['D', 'AH1', 'B', 'AH0', 'L', 'Y', 'UW0']], 'rhyme': [['AA1', 'R']], 'left': [['EH1', 'L']], 'darkness': [['D', 'IY1']], 'gushed': [['JH', 'IY1']], 'midday': [['EH1', 'M']], 'digital': [['D', 'IY1']], 'hold': [['EY1', 'CH']], 'dogtag': [['OW0', 'G', 'AA1', 'T', 'AH0']], 'disguise': [['D', 'IY1']], 'come': [['S', 'IY1']], 'no': [['EH1', 'N']], 'back': [['B', 'IY1']], 'impact': [['AY1']], 'wig': [['D', 'AH1', 'B', 'AH0', 'L', 'Y', 'UW0']], 'rap': [['AA1', 'R']], 'human': [['EY1', 'CH']], 'size': [['EH1', 'S']], 'head': [['EY1', 'CH']], 'rom': [['AA1', 'R']], 'scramble': [['EH1', 'S']], 'sent': [['EH1', 'S']], "year's": [['W', 'AY1']], 'little': [['EH1', 'L']], 'rolled': [['AA1', 'R']], 'click': [['S', 'IY1']], 'you': [['W', 'AY1']], 'with': [['D', 'AH1', 'B', 'AH0', 'L', 'Y', 'UW0']], 'whistlin': [['W', 'IH1', 'S', 'L', 'IH0', 'NG'], ['HH', 'W', 'IH1', 'S', 'L', 'IH0', 'NG']], "it's": [['AY1']], 'kicked': [['K', 'EY1']], 'to': [['T', 'IY1']], 'attached': [['AH0'], ['EY1']], 'who': [['D', 'AH1', 'B', 'AH0', 'L', 'Y', 'UW0']], 'bright': [['B', 'IY1']], 'bloodshot': [['B', 'L', 'AH1', 'D', 'Z', 'W', 'ER2', 'TH']], 'of': [['OW1']], 'and': [['AH0'], ['EY1']], 'prize': [['P', 'IY1']], 'contestant': [['S', 'IY1']], 'thighs': [['T', 'IY1']], 'prisoners': [['P', 'IY1']], 'some': [['EH1', 'S']], 'riot': [['AA1', 'R']], 'through': [['T', 'IY1']], 'calm': [['S', 'IY1']], 'format': [['EH1', 'F']], 'traps': [['T', 'IY1']], 'knows': [['K', 'EY1']], 'bootstraps': [['B', 'IY1']], "'em": ['unk'], 'excrement': [['IY1']], 'explosive': [['IY1']], 'big': [['B', 'IY1']], 'bomb': [['B', 'IY1']], 'wise': [['D', 'AH1', 'B', 'AH0', 'L', 'Y', 'UW0']], 'ears': [['IY1']], 'too': [['T', 'IY1']], 'mission': [['EH1', 'M']], 'murdalizing': [['M', 'AO1', 'R', 'AH0', 'L', 'AY2', 'Z', 'IH0', 'NG']], 'late': [['EH1', 'L']], 'humvee': [['EY1', 'CH']], 'mushed': [['M', 'Y', 'UW1', 'Z', 'D']], 'air': [['AH0'], ['EY1']], 'then': [['T', 'IY1']], 'old': [['OW1']], 'trainin': [['T', 'R', 'EY1', 'N', 'IH0', 'NG']], 'provide': [['P', 'IY1']], 'run': [['AA1', 'R']], 'thought': [['T', 'IY1']], 'sucker': [['EH1', 'S']], 'emcees': [['EH1', 'M', 'S', 'IY1']], 'first': [['EH1', 'F']], 'ambush': [['AH0'], ['EY1']], 'hot': [['EY1', 'CH']], 'roadside': [['AA1', 'R']], 'shade': [['EH1', 'S']], 'buckets': [['B', 'IY1']], 'screaming': [['EH1', 'S']], 'told': [['T', 'IY1']], "where's": [['D', 'AH1', 'B', 'AH0', 'L', 'Y', 'UW0']], 'yucky': [['W', 'AY1']], 'brrrat': [['B', 'R', 'AE1', 'T']], 'stare': [['EH1', 'S']], 'by': [['B', 'IY1']], 'it': [['AY1']], 'propelled': [['P', 'IY1']], 'booby': [['B', 'IY1']], 'hat': [['EY1', 'CH']], 'open': [['OW1']], 'sprayed': [['EH1', 'S']], 'time': [['T', 'IY1']], 'game': [['JH', 'IY1']], 'in': [['AY1']], 'dame': [['D', 'IY1']], 'remains': [['AA1', 'R']], 'eye': [['IY1']], 'since': [['EH1', 'S']], 'fitted': [['EH1', 'F']], 'lucky': [['EH1', 'L']], 'man': [['EH1', 'M']], 'cover': [['S', 'IY1']], 'claim': [['S', 'IY1']], 'lead': [['EH1', 'L']], 'a': [['AH0'], ['EY1']], 'custom': [['S', 'IY1']], 'vision': [['V', 'IY1']], 'rainin': [['R', 'EY1', 'N', 'IH0', 'NG']], 'ringin': [['R', 'IH1', 'NG', 'IH0', 'NG']], 'yell': [['W', 'AY1']], 'brains': [['B', 'IY1']], 'after': [['AH0'], ['EY1']], 'limb-numbing': [['N', 'AH1', 'M', 'IH0', 'NG']], 'spree': [['EH1', 'S']], 'supply': [['EH1', 'S']], 'took': [['T', 'IY1']], 'sun': [['EH1', 'S']], 'for': [['EH1', 'F']], 'support': [['EH1', 'S']], 'abort': [['AH0'], ['EY1']], 'mortars': [['EH1', 'M']], 'quick': [['K', 'Y', 'UW1']], 'last': [['EH1', 'L']], 'incoming': [['AY1']], 'well': [['D', 'AH1', 'B', 'AH0', 'L', 'Y', 'UW0']], 'dragged': [['D', 'IY1']], 'that': [['T', 'IY1']], 'dead': [['D', 'IY1']], 'rpg': [['R', 'AH1', 'G']], 'thick': [['T', 'IY1']], 'like': [['EH1', 'L']], 'fade': [['EH1', 'F']], 'they': [['T', 'IY1']], 'into': [['AY1']], 'same': [['EH1', 'S']], 'sick': [['EH1', 'S']], 'born': [['B', 'I ...

# %% [markdown]
# what you did
# built CMU pronouncing dict into system by creating dictionary of all words in Rap DB to a sylabule value (or list of vals)
# saved as pickle, can't load everytime as it takes a ton of time to build
# also build into words method a new attribute for verses that is dict of word to sylabl
# built scatter plot viz, made a few ad hoc changes
# fixed slight error in rap clean, need to re run artists
# consider loosening filter for uniq_art_verse,up to you
# made changes to regex for [
#
# what's next
# keep modeling and coming up with stuff!

# %%
estconn.close()
